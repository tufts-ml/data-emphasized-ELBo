# %%
import os
import math
import itertools
import numpy as np
import pandas as pd

# %%
def check_epochs(df, n, batch_size=128, steps=6000):
    num_batches = math.floor(n/batch_size)
    epochs = int(steps/num_batches)
    if df.shape[0] == epochs:
        return True
    else:
        return False

# %%
criterion = 'l2-zero'
d = 23717030
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Flowers_102'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

count = -1
for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={d/n}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(128, n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={d/n} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --save"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={d/n} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --save"')
print(count)
# Out:
# -1

# %%
criterion = 'l2-sp'
d = 23717030
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Flowers_102'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

count = -1
for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={d/n}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(128, n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={d/n} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --save"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={d/n} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --save"')
print(count)
# Out:
# -1

# %%
criterion = 'ptyl'
d = 23717030
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Flowers_102'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
prior_directory = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'resnet50_ssl_prior'
random_states = [1001, 2001, 3001]

count = -1
for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={d/n}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(128, n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={d/n} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={d/n} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save"')
print(count)
# Out:
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=46503.98039215686 --lr_0=0.1 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=46503.98039215686 --lr_0=0.1 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=46503.98039215686 --lr_0=0.1 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=23251.99019607843 --lr_0=0.1 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=23251.99019607843 --lr_0=0.1 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=23251.99019607843 --lr_0=0.1 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=46503.98039215686 --lr_0=0.01 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=46503.98039215686 --lr_0=0.01 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=46503.98039215686 --lr_0=0.01 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=23251.99019607843 --lr_0=0.01 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=23251.99019607843 --lr_0=0.01 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=23251.99019607843 --lr_0=0.01 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=46503.98039215686 --lr_0=0.001 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=46503.98039215686 --lr_0=0.001 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=46503.98039215686 --lr_0=0.001 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=23251.99019607843 --lr_0=0.001 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=23251.99019607843 --lr_0=0.001 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=23251.99019607843 --lr_0=0.001 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=46503.98039215686 --lr_0=0.0001 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=46503.98039215686 --lr_0=0.0001 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=46503.98039215686 --lr_0=0.0001 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=23251.99019607843 --lr_0=0.0001 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=23251.99019607843 --lr_0=0.0001 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI' --kappa=23251.99019607843 --lr_0=0.0001 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --save"
# 23

# %%
criterion = 'ptyl'
d = 23717030
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Flowers_102'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

count = -1
for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={d/n}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(128, n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={d/n} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --save"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={d/n} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --save"')
print(count)
# Out:
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI' --kappa=23251.99019607843 --lr_0=0.01 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI' --kappa=46503.98039215686 --lr_0=0.001 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI' --kappa=46503.98039215686 --lr_0=0.001 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI' --kappa=46503.98039215686 --lr_0=0.001 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI' --kappa=23251.99019607843 --lr_0=0.001 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI' --kappa=23251.99019607843 --lr_0=0.001 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI' --kappa=46503.98039215686 --lr_0=0.0001 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI' --kappa=46503.98039215686 --lr_0=0.0001 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI' --kappa=46503.98039215686 --lr_0=0.0001 --model_name='ptyl_kappa=46503.98039215686_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI' --kappa=23251.99019607843 --lr_0=0.0001 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI' --kappa=23251.99019607843 --lr_0=0.0001 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --save"
#     "python ../src/main_Flowers_102.py --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI' --kappa=23251.99019607843 --lr_0=0.0001 --model_name='ptyl_kappa=23251.99019607843_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --save"
# 11

# %%
criterion = 'l2-zero'
d = 23717030
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Flowers_102'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'train_loss', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={d/n}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df.train_loss.values[-1], temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row
    
min_indices = retrained_df.groupby(['criterion', 'n', 'random_state'])['train_loss'].idxmin()
retrained_df = retrained_df.loc[min_indices]

retrained_df
# Out:
#    criterion                                         model_name     n  \
# 12   l2-zero  l2-zero_kappa=46503.98039215686_lr_0=0.001_n=5...   510
# 13   l2-zero  l2-zero_kappa=46503.98039215686_lr_0=0.001_n=5...   510
# 14   l2-zero  l2-zero_kappa=46503.98039215686_lr_0=0.001_n=5...   510
# 15   l2-zero  l2-zero_kappa=23251.99019607843_lr_0=0.001_n=1...  1020
# 16   l2-zero  l2-zero_kappa=23251.99019607843_lr_0=0.001_n=1...  1020
# 17   l2-zero  l2-zero_kappa=23251.99019607843_lr_0=0.001_n=1...  1020
#
#     random_state    train_loss  test_acc  test_nll
# 12          1001  4.735706e+07  0.809863  0.906797
# 13          2001  4.751875e+07  0.811943  0.792949
# 14          3001  4.712169e+07  0.813621  0.869506
# 15          1001  4.131140e+07  0.897944  0.459459
# 16          2001  4.055896e+07  0.905368  0.424271
# 17          3001  4.031733e+07  0.893414  0.464652

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0   l2-zero   510  (l2-zero_kappa=46503.98039215686_lr_0=0.001_n=...
# 1   l2-zero  1020  (l2-zero_kappa=23251.99019607843_lr_0=0.001_n=...
#
#          random_state                                         train_loss  \
# 0  (1001, 2001, 3001)  (47357060.32078432, 47518749.89176471, 4712169...
# 1  (1001, 2001, 3001)  (41311399.69960784, 40558964.00784314, 4031733...
#
#                                             test_acc  \
# 0  (0.8098627328872681, 0.8119431734085083, 0.813...
# 1  (0.8979438543319702, 0.9053683280944824, 0.893...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.9067974177490276, 0.792948923605804, 0.8695...       0.811809
# 1  (0.4594589939609714, 0.4242711879557902, 0.464...       0.898909
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.001537      0.809863      0.813621       0.856418      0.047391
# 1      0.004928      0.893414      0.905368       0.449461      0.017938
#
#    test_nll_min  test_nll_max
# 0      0.792949      0.906797
# 1      0.424271      0.464652

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0   l2-zero   510       0.811809      0.809863      0.813621
# 1   l2-zero  1020       0.898909      0.893414      0.905368

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0   l2-zero   510       0.856418      0.792949      0.906797
# 1   l2-zero  1020       0.449461      0.424271      0.464652

# %%
criterion = 'l2-sp'
d = 23717030
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Flowers_102'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'train_loss', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={d/n}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df.train_loss.values[-1], temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row
    
min_indices = retrained_df.groupby(['criterion', 'n', 'random_state'])['train_loss'].idxmin()
retrained_df = retrained_df.loc[min_indices]

retrained_df
# Out:
#    criterion                                         model_name     n  \
# 12     l2-sp  l2-sp_kappa=46503.98039215686_lr_0=0.001_n=510...   510
# 13     l2-sp  l2-sp_kappa=46503.98039215686_lr_0=0.001_n=510...   510
# 14     l2-sp  l2-sp_kappa=46503.98039215686_lr_0=0.001_n=510...   510
# 15     l2-sp  l2-sp_kappa=23251.99019607843_lr_0=0.001_n=102...  1020
# 16     l2-sp  l2-sp_kappa=23251.99019607843_lr_0=0.001_n=102...  1020
# 17     l2-sp  l2-sp_kappa=23251.99019607843_lr_0=0.001_n=102...  1020
#
#     random_state    train_loss  test_acc  test_nll
# 12          1001  1.266953e+06  0.845076  0.739967
# 13          2001  1.252795e+06  0.845901  0.674580
# 14          3001  1.282993e+06  0.845428  0.715122
# 15          1001  8.477308e+05  0.920676  0.384900
# 16          2001  8.677062e+05  0.916043  0.382284
# 17          3001  8.408495e+05  0.917508  0.386377

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0     l2-sp   510  (l2-sp_kappa=46503.98039215686_lr_0=0.001_n=51...
# 1     l2-sp  1020  (l2-sp_kappa=23251.99019607843_lr_0=0.001_n=10...
#
#          random_state                                         train_loss  \
# 0  (1001, 2001, 3001)  (1266953.4799509805, 1252794.7981862745, 12829...
# 1  (1001, 2001, 3001)  (847730.7596078431, 867706.2320098039, 840849....
#
#                                             test_acc  \
# 0  (0.8450761437416077, 0.8459011316299438, 0.845...
# 1  (0.9206758737564088, 0.9160432815551758, 0.917...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.7399674612112588, 0.6745799600522255, 0.715...       0.845468
# 1  (0.3849003690234035, 0.3822836147734565, 0.386...       0.918076
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.000338      0.845076      0.845901        0.70989      0.026950
# 1      0.001933      0.916043      0.920676        0.38452      0.001693
#
#    test_nll_min  test_nll_max
# 0      0.674580      0.739967
# 1      0.382284      0.386377

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0     l2-sp   510       0.845468      0.845076      0.845901
# 1     l2-sp  1020       0.918076      0.916043      0.920676

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0     l2-sp   510        0.70989      0.674580      0.739967
# 1     l2-sp  1020        0.38452      0.382284      0.386377

# %%
criterion = 'ptyl'
d = 23717030
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Flowers_102'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL_VI'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'train_loss', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={d/n}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df.train_loss.values[-1], temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row
    
min_indices = retrained_df.groupby(['criterion', 'n', 'random_state'])['train_loss'].idxmin()
retrained_df = retrained_df.loc[min_indices]

retrained_df
# Out:
#    criterion                                         model_name     n  \
# 12      ptyl  ptyl_kappa=46503.98039215686_lr_0=0.001_n=510_...   510
# 13      ptyl  ptyl_kappa=46503.98039215686_lr_0=0.001_n=510_...   510
# 14      ptyl  ptyl_kappa=46503.98039215686_lr_0=0.001_n=510_...   510
# 15      ptyl  ptyl_kappa=23251.99019607843_lr_0=0.001_n=1020...  1020
# 16      ptyl  ptyl_kappa=23251.99019607843_lr_0=0.001_n=1020...  1020
# 17      ptyl  ptyl_kappa=23251.99019607843_lr_0=0.001_n=1020...  1020
#
#     random_state    train_loss  test_acc  test_nll
# 12          1001  1.274704e+07  0.766754  1.100265
# 13          2001  9.122694e+06  0.771915  1.045768
# 14          3001  1.131973e+07  0.764609  1.149052
# 15          1001  4.848503e+06  0.846247  0.718988
# 16          2001  4.334889e+06  0.851321  0.697960
# 17          3001  4.432591e+06  0.848625  0.737744

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0      ptyl   510  (ptyl_kappa=46503.98039215686_lr_0=0.001_n=510...
# 1      ptyl  1020  (ptyl_kappa=23251.99019607843_lr_0=0.001_n=102...
#
#          random_state                                         train_loss  \
# 0  (1001, 2001, 3001)  (12747039.875294115, 9122693.536666663, 113197...
# 1  (1001, 2001, 3001)  (4848502.901372549, 4334888.841470588, 4432590...
#
#                                             test_acc  \
# 0  (0.7667543888092041, 0.7719151377677917, 0.764...
# 1  (0.8462473154067993, 0.8513205647468567, 0.848...
#
#                                             test_nll  test_acc_mean  \
# 0  (1.1002652547353269, 1.04576798115131, 1.14905...       0.767760
# 1  (0.7189877552399404, 0.6979597422212076, 0.737...       0.848731
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.003066      0.764609      0.771915       1.098362      0.042187
# 1      0.002073      0.846247      0.851321       0.718231      0.016251
#
#    test_nll_min  test_nll_max
# 0      1.045768      1.149052
# 1      0.697960      0.737744

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0      ptyl   510       0.767760      0.764609      0.771915
# 1      ptyl  1020       0.848731      0.846247      0.851321

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0      ptyl   510       1.098362      1.045768      1.149052
# 1      ptyl  1020       0.718231      0.697960      0.737744

# %%
criterion = 'ptyl'
d = 23717030
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Flowers_102'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_VI'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'train_loss', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={d/n}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df.train_loss.values[-1], temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row
    
min_indices = retrained_df.groupby(['criterion', 'n', 'random_state'])['train_loss'].idxmin()
retrained_df = retrained_df.loc[min_indices]

retrained_df
# Out:
#    criterion                                         model_name     n  \
# 12      ptyl  ptyl_kappa=46503.98039215686_lr_0=0.001_n=510_...   510
# 13      ptyl  ptyl_kappa=46503.98039215686_lr_0=0.001_n=510_...   510
# 14      ptyl  ptyl_kappa=46503.98039215686_lr_0=0.001_n=510_...   510
# 15      ptyl  ptyl_kappa=23251.99019607843_lr_0=0.001_n=1020...  1020
# 16      ptyl  ptyl_kappa=23251.99019607843_lr_0=0.001_n=1020...  1020
# 17      ptyl  ptyl_kappa=23251.99019607843_lr_0=0.001_n=1020...  1020
#
#     random_state    train_loss  test_acc  test_nll
# 12          1001  1.267689e+06  0.845076  0.739919
# 13          2001  1.252394e+06  0.846112  0.674535
# 14          3001  1.283081e+06  0.845330  0.715148
# 15          1001  8.475746e+05  0.920404  0.384899
# 16          2001  8.678351e+05  0.916533  0.382207
# 17          3001  8.405207e+05  0.917508  0.386422

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0      ptyl   510  (ptyl_kappa=46503.98039215686_lr_0=0.001_n=510...
# 1      ptyl  1020  (ptyl_kappa=23251.99019607843_lr_0=0.001_n=102...
#
#          random_state                                         train_loss  \
# 0  (1001, 2001, 3001)  (1267689.2807107845, 1252394.4158578431, 12830...
# 1  (1001, 2001, 3001)  (847574.5674019608, 867835.095882353, 840520.6...
#
#                                             test_acc  \
# 0  (0.8450761437416077, 0.8461123704910278, 0.845...
# 1  (0.9204035997390748, 0.9165334701538086, 0.917...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.7399186043278234, 0.6745351530323137, 0.715...       0.845506
# 1  (0.3848992614712426, 0.3822069112890761, 0.386...       0.918148
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.000441      0.845076      0.846112       0.709867      0.026953
# 1      0.001644      0.916533      0.920404       0.384510      0.001743
#
#    test_nll_min  test_nll_max
# 0      0.674535      0.739919
# 1      0.382207      0.386422

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0      ptyl   510       0.845506      0.845076      0.846112
# 1      ptyl  1020       0.918148      0.916533      0.920404

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0      ptyl   510       0.709867      0.674535      0.739919
# 1      ptyl  1020       0.384510      0.382207      0.386422

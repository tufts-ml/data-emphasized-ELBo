# %%
import os
import math
import itertools
import numpy as np
import pandas as pd

# %%
def check_epochs(df, n, batch_size=128, steps=6000):
    num_batches = math.floor(n/batch_size)
    epochs = int(steps/num_batches)
    if df.shape[0] == epochs:
        return True
    else:
        return False

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-zero'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Oxford-IIIT_Pet'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [370, 3441]
random_states = [1001, 2001, 3001]

count = -1
for alpha, lr_0, n, random_state in itertools.product(alphas, lr_0s, ns, random_states):
    model_name = f'linear_probing_alpha={alpha}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-zero'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Oxford-IIIT_Pet'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [370, 3441]
random_states = [1001, 2001, 3001]

count = -1
for alpha, lr_0, n, random_state in itertools.product(alphas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/main_Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Oxford-IIIT_Pet'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [370, 3441]
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
print(count)
# Out:
# -1

# %%
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'ptyl'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Oxford-IIIT_Pet_SSL'
lambds = np.logspace(start=0, stop=9, num=10)
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [370, 3441]
prior_directory = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'resnet50_ssl_prior'
random_states = [1001, 2001, 3001]

count = -1
for beta, lambd, lr_0, n, random_state in itertools.product(betas, lambds, lr_0s, ns, random_states):
    model_name = f'{criterion}_beta={beta}_lambd={lambd}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Oxford-IIIT_Pet.py --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lambd={lambd} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Oxford-IIIT_Pet.py --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lambd={lambd} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune"')
print(count)
# Out:
# -1

# %%
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'ptyl'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Oxford-IIIT_Pet'
lambds = np.logspace(start=0, stop=9, num=10)
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [370, 3441]
random_states = [1001, 2001, 3001]

count = -1
for beta, lambd, lr_0, n, random_state in itertools.product(betas, lambds, lr_0s, ns, random_states):
    model_name = f'{criterion}_beta={beta}_lambd={lambd}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Oxford-IIIT_Pet.py --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lambd={lambd} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Oxford-IIIT_Pet.py --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lambd={lambd} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Oxford-IIIT_Pet_ConvNeXt_Tiny'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
model_arch = 'ConvNeXt_Tiny'
ns = [370, 3441]
prior_directory = '/cluster/tufts/hugheslab/eharve06/convnext_tiny_torchvision'
prior_type = 'convnext_tiny_torchvision'
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune"')
print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Oxford-IIIT_Pet_ViT_B_16'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
model_arch = 'ViT-B/16'
ns = [370, 3441]
prior_directory = '/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision'
prior_type = 'vit_b_16_torchvision'
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune"')
print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'linear_probing'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/CIFAR-10'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Oxford-IIIT_Pet'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [370, 3441]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

for alpha, lr_0, n, random_state in itertools.product(alphas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_lr_0={lr_0}_n={n}_random_state={random_state}'
    temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
    row = [criterion, model_name, n, random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
    tuned_df.loc[len(tuned_df)] = row
    
min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet'

columns = ['criterion', 'model_name', 'n', 'random_state', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row

retrained_df
# Out:
#         criterion                                         model_name     n  \
# 0  linear_probing  linear_probing_alpha=0.0_lr_0=0.01_n=370_rando...   370
# 1  linear_probing  linear_probing_alpha=0.0001_lr_0=0.1_n=370_ran...   370
# 2  linear_probing  linear_probing_alpha=0.0001_lr_0=0.01_n=370_ra...   370
# 3  linear_probing  linear_probing_alpha=0.0_lr_0=0.01_n=3441_rand...  3441
# 4  linear_probing  linear_probing_alpha=0.0001_lr_0=0.01_n=3441_r...  3441
# 5  linear_probing  linear_probing_alpha=0.0_lr_0=0.01_n=3441_rand...  3441
#
#    random_state  test_acc  test_nll
# 0          1001  0.860543  0.451742
# 1          2001  0.851592  0.516827
# 2          3001  0.865087  0.416913
# 3          1001  0.907926  0.298115
# 4          2001  0.907960  0.295206
# 5          3001  0.908163  0.297041

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#         criterion     n                                         model_name  \
# 0  linear_probing   370  (linear_probing_alpha=0.0_lr_0=0.01_n=370_rand...
# 1  linear_probing  3441  (linear_probing_alpha=0.0_lr_0=0.01_n=3441_ran...
#
#          random_state                                           test_acc  \
# 0  (1001, 2001, 3001)  (0.8605433702468872, 0.8515924215316772, 0.865...
# 1  (1001, 2001, 3001)  (0.9079262018203736, 0.9079595804214478, 0.908...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.4517418358928828, 0.5168270562813763, 0.416...       0.859074
# 1  (0.2981149181622061, 0.2952062479337348, 0.297...       0.908016
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.005606      0.851592      0.865087       0.461827      0.041409
# 1      0.000105      0.907926      0.908163       0.296788      0.001201
#
#    test_nll_min  test_nll_max
# 0      0.416913      0.516827
# 1      0.295206      0.298115

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#         criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0  linear_probing   370       0.859074      0.851592      0.865087
# 1  linear_probing  3441       0.908016      0.907926      0.908163

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#         criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0  linear_probing   370       0.461827      0.416913      0.516827
# 1  linear_probing  3441       0.296788      0.295206      0.298115

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-zero'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/CIFAR-10'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Oxford-IIIT_Pet'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [370, 3441]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

for alpha, lr_0, n, random_state in itertools.product(alphas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_lr_0={lr_0}_n={n}_random_state={random_state}'
    temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
    row = [criterion, model_name, n, random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
    tuned_df.loc[len(tuned_df)] = row
    
min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet'

columns = ['criterion', 'model_name', 'n', 'random_state', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row

retrained_df
# Out:
#   criterion                                         model_name     n  \
# 0   l2-zero  l2-zero_alpha=0.0001_lr_0=0.1_n=370_random_sta...   370
# 1   l2-zero  l2-zero_alpha=1e-06_lr_0=0.01_n=370_random_sta...   370
# 2   l2-zero  l2-zero_alpha=1e-06_lr_0=0.01_n=370_random_sta...   370
# 3   l2-zero  l2-zero_alpha=0.0_lr_0=0.001_n=3441_random_sta...  3441
# 4   l2-zero  l2-zero_alpha=0.0_lr_0=0.001_n=3441_random_sta...  3441
# 5   l2-zero  l2-zero_alpha=1e-06_lr_0=0.001_n=3441_random_s...  3441
#
#    random_state  test_acc  test_nll
# 0          1001  0.867176  0.466061
# 1          2001  0.878054  0.418197
# 2          3001  0.884140  0.365208
# 3          1001  0.933766  0.238797
# 4          2001  0.930155  0.247054
# 5          3001  0.929027  0.242394

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0   l2-zero   370  (l2-zero_alpha=0.0001_lr_0=0.1_n=370_random_st...
# 1   l2-zero  3441  (l2-zero_alpha=0.0_lr_0=0.001_n=3441_random_st...
#
#          random_state                                           test_acc  \
# 0  (1001, 2001, 3001)  (0.8671757578849792, 0.8780539035797119, 0.884...
# 1  (1001, 2001, 3001)  (0.933765947818756, 0.9301549196243286, 0.9290...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.4660609293679313, 0.4181966892816481, 0.365...       0.876457
# 1  (0.2387972432672246, 0.2470542475698948, 0.242...       0.930982
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.007017      0.867176      0.884140       0.416488      0.041191
# 1      0.002021      0.929027      0.933766       0.242748      0.003380
#
#    test_nll_min  test_nll_max
# 0      0.365208      0.466061
# 1      0.238797      0.247054

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0   l2-zero   370       0.876457      0.867176      0.884140
# 1   l2-zero  3441       0.930982      0.929027      0.933766

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0   l2-zero   370       0.416488      0.365208      0.466061
# 1   l2-zero  3441       0.242748      0.238797      0.247054

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/CIFAR-10'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [370, 3441]
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(128, n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state}"')
    else:
        count += 1
        print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state}"')

print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Oxford-IIIT_Pet'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [370, 3441]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
    row = [criterion, model_name, n, random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
    tuned_df.loc[len(tuned_df)] = row
    
min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet'

columns = ['criterion', 'model_name', 'n', 'random_state', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row

retrained_df
# Out:
#   criterion                                         model_name     n  \
# 0     l2-sp  l2-sp_alpha=0.0001_beta=0.0001_lr_0=0.1_n=370_...   370
# 1     l2-sp  l2-sp_alpha=0.0001_beta=0.0001_lr_0=0.1_n=370_...   370
# 2     l2-sp  l2-sp_alpha=0.001_beta=1e-05_lr_0=0.1_n=370_ra...   370
# 3     l2-sp  l2-sp_alpha=0.01_beta=0.0001_lr_0=0.1_n=3441_r...  3441
# 4     l2-sp  l2-sp_alpha=0.01_beta=1e-05_lr_0=0.001_n=3441_...  3441
# 5     l2-sp  l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=3441_ra...  3441
#
#    random_state  test_acc  test_nll
# 0          1001  0.881625  0.427085
# 1          2001  0.870957  0.450819
# 2          3001  0.887986  0.364790
# 3          1001  0.925810  0.302756
# 4          2001  0.929846  0.244896
# 5          3001  0.931024  0.255944

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0     l2-sp   370  (l2-sp_alpha=0.0001_beta=0.0001_lr_0=0.1_n=370...
# 1     l2-sp  3441  (l2-sp_alpha=0.01_beta=0.0001_lr_0=0.1_n=3441_...
#
#          random_state                                           test_acc  \
# 0  (1001, 2001, 3001)  (0.8816245794296265, 0.8709569573402405, 0.887...
# 1  (1001, 2001, 3001)  (0.925809919834137, 0.9298458099365234, 0.9310...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.4270854145999209, 0.4508193630586043, 0.364...       0.880189
# 1  (0.3027560488821197, 0.2448961411202496, 0.255...       0.928893
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.007026      0.870957      0.887986       0.414232      0.036278
# 1      0.002233      0.925810      0.931024       0.267865      0.025080
#
#    test_nll_min  test_nll_max
# 0      0.364790      0.450819
# 1      0.244896      0.302756

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0     l2-sp   370       0.880189      0.870957      0.887986
# 1     l2-sp  3441       0.928893      0.925810      0.931024

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0     l2-sp   370       0.414232      0.364790      0.450819
# 1     l2-sp  3441       0.267865      0.244896      0.302756

# %%
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'ptyl'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Oxford-IIIT_Pet_SSL'
lambds = np.logspace(start=0, stop=9, num=10)
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [370, 3441]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

count = -1
for beta, lambd, lr_0, n, random_state in itertools.product(betas, lambds, lr_0s, ns, random_states):
    model_name = f'{criterion}_beta={beta}_lambd={lambd}_lr_0={lr_0}_n={n}_random_state={random_state}'
    temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
    row = [criterion, model_name, n, random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
    tuned_df.loc[len(tuned_df)] = row
    
min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_SSL'

columns = ['criterion', 'model_name', 'n', 'random_state', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row

retrained_df
# Out:
#   criterion                                         model_name     n  \
# 0      ptyl  ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.001_n...   370
# 1      ptyl  ptyl_beta=0.0001_lambd=100.0_lr_0=0.1_n=370_ra...   370
# 2      ptyl  ptyl_beta=0.0001_lambd=10.0_lr_0=0.1_n=370_ran...   370
# 3      ptyl  ptyl_beta=0.0001_lambd=1.0_lr_0=0.1_n=3441_ran...  3441
# 4      ptyl  ptyl_beta=0.001_lambd=1.0_lr_0=0.1_n=3441_rand...  3441
# 5      ptyl  ptyl_beta=1e-06_lambd=1.0_lr_0=0.1_n=3441_rand...  3441
#
#    random_state  test_acc  test_nll
# 0          1001  0.556214  1.684902
# 1          2001  0.585976  1.679128
# 2          3001  0.607248  1.548829
# 3          1001  0.861418  0.542531
# 4          2001  0.867534  0.504784
# 5          3001  0.858678  0.563874

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0      ptyl   370  (ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.001_...
# 1      ptyl  3441  (ptyl_beta=0.0001_lambd=1.0_lr_0=0.1_n=3441_ra...
#
#          random_state                                           test_acc  \
# 0  (1001, 2001, 3001)  (0.556213915348053, 0.585975706577301, 0.60724...
# 1  (1001, 2001, 3001)  (0.861417829990387, 0.8675336837768555, 0.8586...
#
#                                             test_nll  test_acc_mean  \
# 0  (1.6849021834942457, 1.679128403363419, 1.5488...       0.583146
# 1  (0.542531016786601, 0.5047839216199549, 0.5638...       0.862543
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.020930      0.556214      0.607248       1.637620      0.062829
# 1      0.003702      0.858678      0.867534       0.537063      0.024431
#
#    test_nll_min  test_nll_max
# 0      1.548829      1.684902
# 1      0.504784      0.563874

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0      ptyl   370       0.583146      0.556214      0.607248
# 1      ptyl  3441       0.862543      0.858678      0.867534

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0      ptyl   370       1.637620      1.548829      1.684902
# 1      ptyl  3441       0.537063      0.504784      0.563874

# %%
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'ptyl'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Oxford-IIIT_Pet'
lambds = np.logspace(start=0, stop=9, num=10)
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [370, 3441]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

count = -1
for beta, lambd, lr_0, n, random_state in itertools.product(betas, lambds, lr_0s, ns, random_states):
    model_name = f'{criterion}_beta={beta}_lambd={lambd}_lr_0={lr_0}_n={n}_random_state={random_state}'
    temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
    row = [criterion, model_name, n, random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
    tuned_df.loc[len(tuned_df)] = row
    
min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet'

columns = ['criterion', 'model_name', 'n', 'random_state', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row

retrained_df
# Out:
#   criterion                                         model_name     n  \
# 0      ptyl  ptyl_beta=0.0001_lambd=1000.0_lr_0=0.1_n=370_r...   370
# 1      ptyl  ptyl_beta=0.0001_lambd=100.0_lr_0=0.1_n=370_ra...   370
# 2      ptyl  ptyl_beta=0.0001_lambd=10.0_lr_0=0.1_n=370_ran...   370
# 3      ptyl  ptyl_beta=0.0001_lambd=1.0_lr_0=0.1_n=3441_ran...  3441
# 4      ptyl  ptyl_beta=0.0001_lambd=1.0_lr_0=0.001_n=3441_r...  3441
# 5      ptyl  ptyl_beta=0.001_lambd=1.0_lr_0=0.1_n=3441_rand...  3441
#
#    random_state  test_acc  test_nll
# 0          1001  0.875018  0.456243
# 1          2001  0.880415  0.420211
# 2          3001  0.881502  0.370669
# 3          1001  0.929574  0.305188
# 4          2001  0.927643  0.209936
# 5          3001  0.931846  0.263618

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0      ptyl   370  (ptyl_beta=0.0001_lambd=1000.0_lr_0=0.1_n=370_...
# 1      ptyl  3441  (ptyl_beta=0.0001_lambd=1.0_lr_0=0.1_n=3441_ra...
#
#          random_state                                           test_acc  \
# 0  (1001, 2001, 3001)  (0.8750179409980774, 0.8804153800010681, 0.881...
# 1  (1001, 2001, 3001)  (0.929574191570282, 0.9276434183120728, 0.9318...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.4562432067181928, 0.4202107375350107, 0.370...       0.878978
# 1  (0.3051881858097675, 0.2099362726128378, 0.263...       0.929688
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.002835      0.875018      0.881502       0.415708      0.035080
# 1      0.001718      0.927643      0.931846       0.259581      0.038991
#
#    test_nll_min  test_nll_max
# 0      0.370669      0.456243
# 1      0.209936      0.305188

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0      ptyl   370       0.878978      0.875018      0.881502
# 1      ptyl  3441       0.929688      0.927643      0.931846

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0      ptyl   370       0.415708      0.370669      0.456243
# 1      ptyl  3441       0.259581      0.209936      0.305188

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
model_arch = 'ViT-B/16'
ns = [370, 3441]
prior_directory = '/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision'
prior_type = 'vit_b_16_torchvision'
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(128, n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state}"')
    else:
        count += 1
        print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state}"')
print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Oxford-IIIT_Pet_ViT_B_16'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [370, 3441]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        tuned_df.loc[len(tuned_df)] = row
    
min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16'

columns = ['criterion', 'model_name', 'n', 'random_state', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row

retrained_df
# Out:
#   criterion                                         model_name     n  \
# 0     l2-sp  l2-sp_alpha=0.001_beta=1e-06_lr_0=0.1_n=370_ra...   370
# 1     l2-sp  l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=370_ran...   370
# 2     l2-sp  l2-sp_alpha=0.01_beta=1e-06_lr_0=0.1_n=370_ran...   370
# 3     l2-sp  l2-sp_alpha=1e-06_beta=0.001_lr_0=0.001_n=3441...  3441
# 4     l2-sp  l2-sp_alpha=0.0001_beta=0.0001_lr_0=0.01_n=344...  3441
# 5     l2-sp  l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=3441_ra...  3441
#
#    random_state  test_acc  test_nll
# 0          1001  0.893566  0.382000
# 1          2001  0.879699  0.416098
# 2          3001  0.870878  0.465176
# 3          1001  0.931604  0.235021
# 4          2001  0.934785  0.288926
# 5          3001  0.932843  0.239450

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0     l2-sp   370  (l2-sp_alpha=0.001_beta=1e-06_lr_0=0.1_n=370_r...
# 1     l2-sp  3441  (l2-sp_alpha=1e-06_beta=0.001_lr_0=0.001_n=344...
#
#          random_state                                           test_acc  \
# 0  (1001, 2001, 3001)  (0.893566370010376, 0.879699170589447, 0.87087...
# 1  (1001, 2001, 3001)  (0.9316037893295288, 0.9347853660583496, 0.932...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.3819999361950645, 0.4160983631055844, 0.465...       0.881381
# 1  (0.2350212280412856, 0.2889255893922596, 0.239...       0.933077
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.009338      0.870878      0.893566       0.421091      0.034139
# 1      0.001309      0.931604      0.934785       0.254466      0.024434
#
#    test_nll_min  test_nll_max
# 0      0.382000      0.465176
# 1      0.235021      0.288926

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0     l2-sp   370       0.881381      0.870878      0.893566
# 1     l2-sp  3441       0.933077      0.931604      0.934785

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0     l2-sp   370       0.421091      0.382000      0.465176
# 1     l2-sp  3441       0.254466      0.235021      0.288926

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ConvNeXt_Tiny'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
model_arch = 'ConvNeXt_Tiny'
ns = [370, 3441]
prior_directory = '/cluster/tufts/hugheslab/eharve06/convnext_tiny_torchvision'
prior_type = 'convnext_tiny_torchvision'
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(128, n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state}"')
    else:
        count += 1
        print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state}"')
print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Oxford-IIIT_Pet_ConvNeXt_Tiny'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [370, 3441]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        tuned_df.loc[len(tuned_df)] = row
    
min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ConvNeXt_Tiny'

columns = ['criterion', 'model_name', 'n', 'random_state', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row

retrained_df
# Out:
#   criterion                                         model_name     n  \
# 0     l2-sp  l2-sp_alpha=0.001_beta=0.0001_lr_0=0.01_n=370_...   370
# 1     l2-sp  l2-sp_alpha=0.0001_beta=0.0_lr_0=0.1_n=370_ran...   370
# 2     l2-sp  l2-sp_alpha=0.01_beta=1e-06_lr_0=0.01_n=370_ra...   370
# 3     l2-sp  l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=3441_ra...  3441
# 4     l2-sp  l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=3441_ra...  3441
# 5     l2-sp  l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=3441_ra...  3441
#
#    random_state  test_acc  test_nll
# 0          1001  0.894371  0.386805
# 1          2001  0.874235  0.460078
# 2          3001  0.903782  0.295017
# 3          1001  0.941576  0.177188
# 4          2001  0.945106  0.178005
# 5          3001  0.942891  0.176076

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0     l2-sp   370  (l2-sp_alpha=0.001_beta=0.0001_lr_0=0.01_n=370...
# 1     l2-sp  3441  (l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=3441_r...
#
#          random_state                                           test_acc  \
# 0  (1001, 2001, 3001)  (0.8943705558776855, 0.8742351531982422, 0.903...
# 1  (1001, 2001, 3001)  (0.9415759444236756, 0.945106029510498, 0.9428...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.3868054691524442, 0.4600779478874543, 0.295...       0.890796
# 1  (0.17718840731218, 0.1780047836505601, 0.17607...       0.943191
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.012324      0.874235      0.903782       0.380633      0.067527
# 1      0.001457      0.941576      0.945106       0.177090      0.000791
#
#    test_nll_min  test_nll_max
# 0      0.295017      0.460078
# 1      0.176076      0.178005

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0     l2-sp   370       0.890796      0.874235      0.903782
# 1     l2-sp  3441       0.943191      0.941576      0.945106

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0     l2-sp   370       0.380633      0.295017      0.460078
# 1     l2-sp  3441       0.177090      0.176076      0.178005

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
model_arch = 'ViT-B/16'
ns = [370, 3441]
prior_directory = '/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision'
prior_type = 'vit_b_16_torchvision'
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(128, n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state}"')
    else:
        count += 1
        print(f'    "python ../src/main_Oxford-IIIT_Pet.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state}"')
print(count)
# Out:
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.1_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.1_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.1_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.1_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.1_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.1_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.01_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.01_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.01_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.01_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.01_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.01_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.001_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.001_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.001_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.001_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.001_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.001_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.0001_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.0001_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.0001_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.0001_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.0001_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.0001_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.01_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.01_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.01_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.01_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.01_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.01_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.001_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.001_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.001_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.001_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.001_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.001_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.0001_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.0001_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.0001_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.0001_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.0001_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.0001_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.1_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.1_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.1_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.1_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.1_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.1_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.01_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.01_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.01_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.01_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.01_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.01_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.001_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.001_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.001_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.001_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.001_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.001_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.0001_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.0001_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.0001_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.0001_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.0001_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.0001_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.01_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.01_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.01_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.01_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.01_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
# ...
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.0001_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.0001_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.0001_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.1_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.1_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.1_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.1_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.1_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.1 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.1_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.01_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.01_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.01_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.01_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.01_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.01 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.01_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.001_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.001_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.001_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.001_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.001_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.001_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.0001_n=370_random_state=1001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.0001_n=370_random_state=2001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.0001_n=370_random_state=3001' --n=370 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.0001_n=3441_random_state=1001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=1001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.0001_n=3441_random_state=2001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=2001"
#     "python ../src/main_Oxford-IIIT_Pet.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16' --lr_0=0.0001 --model_arch='ViT-B/16' --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.0001_n=3441_random_state=3001' --n=3441 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/vit_b_16_torchvision' --prior_type='vit_b_16_torchvision' --random_state=3001"
# 863

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Oxford-IIIT_Pet_ViT_B_16'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [370, 3441]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        tuned_df.loc[len(tuned_df)] = row
    
min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ViT_B_16'

columns = ['criterion', 'model_name', 'n', 'random_state', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    print(row.model_name)
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row

retrained_df
# Out:
# l2-sp_alpha=0.001_beta=1e-06_lr_0=0.1_n=370_random_state=1001
# l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=370_random_state=2001
# l2-sp_alpha=0.01_beta=1e-06_lr_0=0.1_n=370_random_state=3001
# l2-sp_alpha=1e-06_beta=0.001_lr_0=0.001_n=3441_random_state=1001
# l2-sp_alpha=0.0001_beta=0.0001_lr_0=0.01_n=3441_random_state=2001
# l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=3441_random_state=3001
#   criterion                                         model_name     n  \
# 0     l2-sp  l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=370_ran...   370
# 1     l2-sp  l2-sp_alpha=0.01_beta=1e-06_lr_0=0.1_n=370_ran...   370
# 2     l2-sp  l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=3441_ra...  3441
#
#    random_state  test_acc  test_nll
# 0          2001  0.000000  0.000000
# 1          3001  0.000000  0.000000
# 2          3001  0.930637  0.240307

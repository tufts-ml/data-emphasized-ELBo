# %%
import os
import math
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 11})
import matplotlib.ticker as ticker
# PyTorch
import torch
import torchvision

# %%
def check_epochs(df, n, batch_size=128, steps=6000):
    num_batches = math.floor(n/batch_size)
    epochs = int(steps/num_batches)
    if df.shape[0] == epochs:
        return True
    else:
        return False

# %%
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/CIFAR-10'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_CIFAR-10_ConvNeXt_Tiny_VI'
kappas = torch.logspace(0, math.log10(27827818), 10)[1:]
lr_0s = [0.1, 0.01, 0.001, 0.0001]
model_arch = 'ConvNeXt_Tiny'
ns = [100, 1000, 10000, 50000]
prior_directory = '/cluster/tufts/hugheslab/eharve06/convnext_tiny_torchvision'
prior_type = 'convnext_tiny_torchvision'
random_states = [1001, 2001, 3001]

count = -1
for kappa, lr_0, n, random_state in itertools.product(kappas, lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={kappa}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(128, n), steps=6000):
            count += 1
            print(f'    "python ../src/main_CIFAR-10.py --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={kappa} --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save"')
    else:
        count += 1
        print(f'    "python ../src/main_CIFAR-10.py --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={kappa} --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save"')
print(count)
# Out:
# -1

# %%
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Flowers_102'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_ConvNeXt_Tiny_VI'
kappas = torch.logspace(0, math.log10(27898566), 10)[1:]
lr_0s = [0.1, 0.01, 0.001, 0.0001]
model_arch = 'ConvNeXt_Tiny'
ns = [510, 1020]
prior_directory = '/cluster/tufts/hugheslab/eharve06/convnext_tiny_torchvision'
prior_type = 'convnext_tiny_torchvision'
random_states = [1001, 2001, 3001]

count = -1
for kappa, lr_0, n, random_state in itertools.product(kappas, lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={kappa}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(128, n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={kappa} --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={kappa} --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save"')
print(count)
# Out:
# -1

# %%
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ConvNeXt_Tiny_VI'
kappas = torch.logspace(0, math.log10(27848581), 10)[1:]
lr_0s = [0.1, 0.01, 0.001, 0.0001]
model_arch = 'ConvNeXt_Tiny'
ns = [370, 3441]
prior_directory = '/cluster/tufts/hugheslab/eharve06/convnext_tiny_torchvision'
prior_type = 'convnext_tiny_torchvision'
random_states = [1001, 2001, 3001]

count = -1
for kappa, lr_0, n, random_state in itertools.product(kappas, lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={kappa}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(128, n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Oxford-IIIT_Pet.py --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={kappa} --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save"')
    else:
        count += 1
        print(f'    "python ../src/main_Oxford-IIIT_Pet.py --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={kappa} --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --save"')
print(count)
# Out:
# -1

# %%
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/CIFAR-10'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_CIFAR-10_ConvNeXt_Tiny_VI'
kappas = torch.logspace(0, math.log10(27827818), 10)
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [100, 1000, 10000, 50000]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'kappa', 'model_name', 'n', 'random_state', 'train_loss', 'test_acc', 'test_nll']
cifar10_retrained_df = pd.DataFrame(columns=columns)

for kappa, lr_0, n, random_state in itertools.product(kappas, lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={kappa}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, kappa.item(), model_name, n, random_state, temp_df.train_loss.values[-1], temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        cifar10_retrained_df.loc[len(cifar10_retrained_df)] = row
        
for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={27827818/n}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, 27827818/n, model_name, n, random_state, temp_df.train_loss.values[-1], temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        cifar10_retrained_df.loc[len(cifar10_retrained_df)] = row
    
min_indices = cifar10_retrained_df.groupby(['criterion', 'kappa', 'n', 'random_state'])['train_loss'].idxmin()
cifar10_retrained_df = cifar10_retrained_df.loc[min_indices]

cifar10_retrained_df
# Out:
#     criterion       kappa                                         model_name  \
# 12      l2-sp         1.0  l2-sp_kappa=1.0_lr_0=0.01_n=100_random_state=1001
# 13      l2-sp         1.0  l2-sp_kappa=1.0_lr_0=0.01_n=100_random_state=2001
# 38      l2-sp         1.0  l2-sp_kappa=1.0_lr_0=0.0001_n=100_random_state...
# 15      l2-sp         1.0  l2-sp_kappa=1.0_lr_0=0.01_n=1000_random_state=...
# 16      l2-sp         1.0  l2-sp_kappa=1.0_lr_0=0.01_n=1000_random_state=...
# ..        ...         ...                                                ...
# 451     l2-sp  27827808.0  l2-sp_kappa=27827808.0_lr_0=0.01_n=10000_rando...
# 452     l2-sp  27827808.0  l2-sp_kappa=27827808.0_lr_0=0.01_n=10000_rando...
# 441     l2-sp  27827808.0  l2-sp_kappa=27827808.0_lr_0=0.1_n=50000_random...
# 442     l2-sp  27827808.0  l2-sp_kappa=27827808.0_lr_0=0.1_n=50000_random...
# 443     l2-sp  27827808.0  l2-sp_kappa=27827808.0_lr_0=0.1_n=50000_random...
#
# ...

# %%
cifar10_grouped_df = cifar10_retrained_df.groupby(['criterion', 'kappa', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    cifar10_grouped_df[f'{column}_mean'] = cifar10_grouped_df[column].apply(lambda item: np.mean(item))
    cifar10_grouped_df[f'{column}_std'] = cifar10_grouped_df[column].apply(lambda item: np.std(item))
    cifar10_grouped_df[f'{column}_min'] = cifar10_grouped_df[column].apply(lambda item: np.min(item))
    cifar10_grouped_df[f'{column}_max'] = cifar10_grouped_df[column].apply(lambda item: np.max(item))
cifar10_grouped_df = cifar10_grouped_df.reset_index()
cifar10_grouped_df
# Out:
#    criterion         kappa      n  \
# 0      l2-sp  1.000000e+00    100
# 1      l2-sp  1.000000e+00   1000
# 2      l2-sp  1.000000e+00  10000
# 3      l2-sp  1.000000e+00  50000
# 4      l2-sp  6.716830e+00    100
# 5      l2-sp  6.716830e+00   1000
# 6      l2-sp  6.716830e+00  10000
# 7      l2-sp  6.716830e+00  50000
# 8      l2-sp  4.511580e+01    100
# 9      l2-sp  4.511580e+01   1000
# 10     l2-sp  4.511580e+01  10000
# 11     l2-sp  4.511580e+01  50000
# 12     l2-sp  3.030352e+02    100
# 13     l2-sp  3.030352e+02   1000
# 14     l2-sp  3.030352e+02  10000
# 15     l2-sp  3.030352e+02  50000
# 16     l2-sp  5.565564e+02  50000
# 17     l2-sp  2.035435e+03    100
# 18     l2-sp  2.035435e+03   1000
# 19     l2-sp  2.035435e+03  10000
# 20     l2-sp  2.035435e+03  50000
# 21     l2-sp  2.782782e+03  10000
# 22     l2-sp  1.367167e+04    100
# 23     l2-sp  1.367167e+04   1000
# 24     l2-sp  1.367167e+04  10000
# 25     l2-sp  1.367167e+04  50000
# ...

# %%
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Flowers_102'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Flowers_102_ConvNeXt_Tiny_VI'
kappas = torch.logspace(0, math.log10(27898566), 10)
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'kappa', 'model_name', 'n', 'random_state', 'train_loss', 'test_acc', 'test_nll']
flower102_retrained_df = pd.DataFrame(columns=columns)

for kappa, lr_0, n, random_state in itertools.product(kappas, lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={kappa}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, kappa.item(), model_name, n, random_state, temp_df.train_loss.values[-1], temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        flower102_retrained_df.loc[len(flower102_retrained_df)] = row
        
for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={27827818/n}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, 27898566/n, model_name, n, random_state, temp_df.train_loss.values[-1], temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        flower102_retrained_df.loc[len(flower102_retrained_df)] = row
    
min_indices = flower102_retrained_df.groupby(['criterion', 'kappa', 'n', 'random_state'])['train_loss'].idxmin()
flower102_retrained_df = flower102_retrained_df.loc[min_indices]

flower102_retrained_df
# Out:
#     criterion         kappa  \
# 6       l2-sp  1.000000e+00
# 7       l2-sp  1.000000e+00
# 8       l2-sp  1.000000e+00
# 9       l2-sp  1.000000e+00
# 10      l2-sp  1.000000e+00
# 11      l2-sp  1.000000e+00
# 30      l2-sp  6.718725e+00
# 31      l2-sp  6.718725e+00
# 32      l2-sp  6.718725e+00
# 33      l2-sp  6.718725e+00
# 34      l2-sp  6.718725e+00
# 35      l2-sp  6.718725e+00
# 54      l2-sp  4.514127e+01
# 55      l2-sp  4.514127e+01
# 56      l2-sp  4.514127e+01
# 57      l2-sp  4.514127e+01
# 58      l2-sp  4.514127e+01
# 59      l2-sp  4.514127e+01
# 72      l2-sp  3.032918e+02
# 79      l2-sp  3.032918e+02
# 80      l2-sp  3.032918e+02
# 81      l2-sp  3.032918e+02
# 82      l2-sp  3.032918e+02
# 83      l2-sp  3.032918e+02
# 102     l2-sp  2.037734e+03
# 103     l2-sp  2.037734e+03
# 104     l2-sp  2.037734e+03
# 105     l2-sp  2.037734e+03
# 106     l2-sp  2.037734e+03
# 107     l2-sp  2.037734e+03
# 120     l2-sp  1.369098e+04
# 121     l2-sp  1.369098e+04
# ...

# %%
flower102_grouped_df = flower102_retrained_df.groupby(['criterion', 'kappa', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    flower102_grouped_df[f'{column}_mean'] = flower102_grouped_df[column].apply(lambda item: np.mean(item))
    flower102_grouped_df[f'{column}_std'] = flower102_grouped_df[column].apply(lambda item: np.std(item))
    flower102_grouped_df[f'{column}_min'] = flower102_grouped_df[column].apply(lambda item: np.min(item))
    flower102_grouped_df[f'{column}_max'] = flower102_grouped_df[column].apply(lambda item: np.max(item))
flower102_grouped_df = flower102_grouped_df.reset_index()
flower102_grouped_df
# Out:
#    criterion         kappa     n  \
# 0      l2-sp  1.000000e+00   510
# 1      l2-sp  1.000000e+00  1020
# 2      l2-sp  6.718725e+00   510
# 3      l2-sp  6.718725e+00  1020
# 4      l2-sp  4.514127e+01   510
# 5      l2-sp  4.514127e+01  1020
# 6      l2-sp  3.032918e+02   510
# 7      l2-sp  3.032918e+02  1020
# 8      l2-sp  2.037734e+03   510
# 9      l2-sp  2.037734e+03  1020
# 10     l2-sp  1.369098e+04   510
# 11     l2-sp  1.369098e+04  1020
# 12     l2-sp  9.198591e+04   510
# 13     l2-sp  9.198591e+04  1020
# 14     l2-sp  6.180280e+05   510
# 15     l2-sp  6.180280e+05  1020
# 16     l2-sp  4.152360e+06   510
# 17     l2-sp  4.152360e+06  1020
# 18     l2-sp  2.789857e+07   510
# 19     l2-sp  2.789857e+07  1020
#
#                                            model_name        random_state  \
# 0   (l2-sp_kappa=1.0_lr_0=0.01_n=510_random_state=...  (1001, 2001, 3001)
# 1   (l2-sp_kappa=1.0_lr_0=0.01_n=1020_random_state...  (1001, 2001, 3001)
# ...

# %%
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Oxford-IIIT_Pet'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_Oxford-IIIT_Pet_ConvNeXt_Tiny_VI'
kappas = torch.logspace(0, math.log10(27848581), 10)
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [370, 3441]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'kappa', 'model_name', 'n', 'random_state', 'train_loss', 'test_acc', 'test_nll']
pet37_retrained_df = pd.DataFrame(columns=columns)

for kappa, lr_0, n, random_state in itertools.product(kappas, lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={kappa}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, kappa.item(), model_name, n, random_state, temp_df.train_loss.values[-1], temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        pet37_retrained_df.loc[len(pet37_retrained_df)] = row
        
for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={27827818/n}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, 27848581/n, model_name, n, random_state, temp_df.train_loss.values[-1], temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        pet37_retrained_df.loc[len(pet37_retrained_df)] = row
    
min_indices = pet37_retrained_df.groupby(['criterion', 'kappa', 'n', 'random_state'])['train_loss'].idxmin()
pet37_retrained_df = pet37_retrained_df.loc[min_indices]

pet37_retrained_df
# Out:
#     criterion         kappa  \
# 6       l2-sp  1.000000e+00
# 7       l2-sp  1.000000e+00
# 8       l2-sp  1.000000e+00
# 15      l2-sp  1.000000e+00
# 16      l2-sp  1.000000e+00
# 17      l2-sp  1.000000e+00
# 30      l2-sp  6.717387e+00
# 31      l2-sp  6.717387e+00
# 32      l2-sp  6.717387e+00
# 33      l2-sp  6.717387e+00
# 34      l2-sp  6.717387e+00
# 35      l2-sp  6.717387e+00
# 54      l2-sp  4.512329e+01
# 55      l2-sp  4.512329e+01
# 56      l2-sp  4.512329e+01
# 57      l2-sp  4.512329e+01
# 58      l2-sp  4.512329e+01
# 59      l2-sp  4.512329e+01
# 78      l2-sp  3.031106e+02
# 79      l2-sp  3.031106e+02
# 80      l2-sp  3.031106e+02
# 81      l2-sp  3.031106e+02
# 82      l2-sp  3.031106e+02
# 83      l2-sp  3.031106e+02
# 102     l2-sp  2.036111e+03
# 103     l2-sp  2.036111e+03
# 104     l2-sp  2.036111e+03
# 105     l2-sp  2.036111e+03
# 106     l2-sp  2.036111e+03
# 107     l2-sp  2.036111e+03
# 126     l2-sp  1.367734e+04
# 127     l2-sp  1.367734e+04
# ...

# %%
pet37_grouped_df = pet37_retrained_df.groupby(['criterion', 'kappa', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    pet37_grouped_df[f'{column}_mean'] = pet37_grouped_df[column].apply(lambda item: np.mean(item))
    pet37_grouped_df[f'{column}_std'] = pet37_grouped_df[column].apply(lambda item: np.std(item))
    pet37_grouped_df[f'{column}_min'] = pet37_grouped_df[column].apply(lambda item: np.min(item))
    pet37_grouped_df[f'{column}_max'] = pet37_grouped_df[column].apply(lambda item: np.max(item))
pet37_grouped_df = pet37_grouped_df.reset_index()
pet37_grouped_df
# Out:
#    criterion         kappa     n  \
# 0      l2-sp  1.000000e+00   370
# 1      l2-sp  1.000000e+00  3441
# 2      l2-sp  6.717387e+00   370
# 3      l2-sp  6.717387e+00  3441
# 4      l2-sp  4.512329e+01   370
# 5      l2-sp  4.512329e+01  3441
# 6      l2-sp  3.031106e+02   370
# 7      l2-sp  3.031106e+02  3441
# 8      l2-sp  2.036111e+03   370
# 9      l2-sp  2.036111e+03  3441
# 10     l2-sp  1.367734e+04   370
# 11     l2-sp  1.367734e+04  3441
# 12     l2-sp  9.187602e+04   370
# 13     l2-sp  9.187602e+04  3441
# 14     l2-sp  6.171668e+05   370
# 15     l2-sp  6.171668e+05  3441
# 16     l2-sp  4.145748e+06   370
# 17     l2-sp  4.145748e+06  3441
# 18     l2-sp  2.784859e+07   370
# 19     l2-sp  2.784859e+07  3441
#
#                                            model_name        random_state  \
# 0   (l2-sp_kappa=1.0_lr_0=0.01_n=370_random_state=...  (1001, 2001, 3001)
# 1   (l2-sp_kappa=1.0_lr_0=0.001_n=3441_random_stat...  (1001, 2001, 3001)
# ...

# %%
ncols, nrows = 4, 2
fig, axs = plt.subplots(figsize=(4*ncols, 3*nrows), ncols=ncols, nrows=nrows)

D = 27827818
N = 100
axs[0,0].set_title(rf'CIFAR-10 $N={N}$')
axs[0,0].plot(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean, color='#1F77B4')
axs[0,0].fill_between(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std, cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std, alpha=0.1, color='#1F77B4')
axs[0,0].vlines(D/N, (cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std).min(), (cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std).max(), color='#000000', linestyle='dashed')
axs[0,0].set_xscale('log')
axs[0,0].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[0,0].set_xlabel(r'$\kappa$')
axs[0,0].set_ylabel('Test accuracy')
axs[0,0].grid()

N = 1000
axs[0,1].set_title(rf'CIFAR-10 $N={N}$')
axs[0,1].plot(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean, color='#1F77B4')
axs[0,1].fill_between(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std, cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std, alpha=0.1, color='#1F77B4')
axs[0,1].vlines(D/N, (cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std).min(), (cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std).max(), color='#000000', linestyle='dashed')
axs[0,1].set_xscale('log')
axs[0,1].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[0,1].set_xlabel(r'$\kappa$')
axs[0,1].set_ylabel('Test accuracy')
axs[0,1].grid()

N = 10000
axs[0,2].set_title(rf'CIFAR-10 $N={N}$')
axs[0,2].plot(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean, color='#1F77B4')
axs[0,2].fill_between(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std, cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std, alpha=0.1, color='#1F77B4')
axs[0,2].vlines(D/N, (cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std).min(), (cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std).max(), color='#000000', linestyle='dashed')
axs[0,2].set_xscale('log')
axs[0,2].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[0,2].set_xlabel(r'$\kappa$')
axs[0,2].set_ylabel('Test accuracy')
axs[0,2].grid()

N = 50000
axs[0,3].set_title(rf'CIFAR-10 $N={N}$')
axs[0,3].plot(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean, color='#1F77B4')
axs[0,3].fill_between(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std, cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std, alpha=0.1, color='#1F77B4')
axs[0,3].vlines(D/N, (cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std).min(), (cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std).max(), color='#000000', linestyle='dashed')
axs[0,3].set_xscale('log')
axs[0,3].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[0,3].set_xlabel(r'$\kappa$')
axs[0,3].set_ylabel('Test accuracy')
axs[0,3].grid()

D = 27898566
N = 510
axs[1,0].set_title(rf'Flower-102 $N={N}$')
axs[1,0].plot(flower102_grouped_df[flower102_grouped_df.n==N].kappa, flower102_grouped_df[flower102_grouped_df.n==N].test_acc_mean, color='#1F77B4', label='iso DE-ELBO (ours)')
axs[1,0].fill_between(flower102_grouped_df[flower102_grouped_df.n==N].kappa, flower102_grouped_df[flower102_grouped_df.n==N].test_acc_mean-flower102_grouped_df[flower102_grouped_df.n==N].test_acc_std, flower102_grouped_df[flower102_grouped_df.n==N].test_acc_mean+flower102_grouped_df[flower102_grouped_df.n==N].test_acc_std, alpha=0.1, color='#1F77B4')
axs[1,0].vlines(D/N, (flower102_grouped_df[flower102_grouped_df.n==N].test_acc_mean-flower102_grouped_df[flower102_grouped_df.n==N].test_acc_std).min(), (flower102_grouped_df[flower102_grouped_df.n==N].test_acc_mean+flower102_grouped_df[flower102_grouped_df.n==N].test_acc_std).max(), color='#000000', linestyle='dashed')
axs[1,0].text(D/N, (1/2) * (flower102_grouped_df[flower102_grouped_df.n==N].test_acc_mean.min() + flower102_grouped_df[flower102_grouped_df.n==N].test_acc_mean.max()), r'$\frac{D}{N}$  ', ha='right', va='center')
axs[1,0].set_xscale('log')
axs[1,0].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[1,0].set_xlabel(r'$\kappa$')
axs[1,0].set_ylabel('Test accuracy')
axs[1,0].legend(loc='lower left')
axs[1,0].grid()

N = 1020
axs[1,1].set_title(rf'Flower-102 $N={N}$')
axs[1,1].plot(flower102_grouped_df[flower102_grouped_df.n==N].kappa, flower102_grouped_df[flower102_grouped_df.n==N].test_acc_mean, color='#1F77B4')
axs[1,1].fill_between(flower102_grouped_df[flower102_grouped_df.n==N].kappa, flower102_grouped_df[flower102_grouped_df.n==N].test_acc_mean-flower102_grouped_df[flower102_grouped_df.n==N].test_acc_std, flower102_grouped_df[flower102_grouped_df.n==N].test_acc_mean+flower102_grouped_df[flower102_grouped_df.n==N].test_acc_std, alpha=0.1, color='#1F77B4')
axs[1,1].vlines(D/N, (flower102_grouped_df[flower102_grouped_df.n==N].test_acc_mean-flower102_grouped_df[flower102_grouped_df.n==N].test_acc_std).min(), (flower102_grouped_df[flower102_grouped_df.n==N].test_acc_mean+flower102_grouped_df[flower102_grouped_df.n==N].test_acc_std).max(), color='#000000', linestyle='dashed')
axs[1,1].set_xscale('log')
axs[1,1].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[1,1].set_xlabel(r'$\kappa$')
axs[1,1].set_ylabel('Test accuracy')
axs[1,1].grid()

D = 27848581
N = 370
axs[1,2].set_title(rf'Pet-37 $N={N}$')
axs[1,2].plot(pet37_grouped_df[pet37_grouped_df.n==N].kappa, pet37_grouped_df[pet37_grouped_df.n==N].test_acc_mean, color='#1F77B4')
axs[1,2].fill_between(pet37_grouped_df[pet37_grouped_df.n==N].kappa, pet37_grouped_df[pet37_grouped_df.n==N].test_acc_mean-pet37_grouped_df[pet37_grouped_df.n==N].test_acc_std, pet37_grouped_df[pet37_grouped_df.n==N].test_acc_mean+pet37_grouped_df[pet37_grouped_df.n==N].test_acc_std, alpha=0.1, color='#1F77B4')
axs[1,2].vlines(D/N, (pet37_grouped_df[pet37_grouped_df.n==N].test_acc_mean-pet37_grouped_df[pet37_grouped_df.n==N].test_acc_std).min(), (pet37_grouped_df[pet37_grouped_df.n==N].test_acc_mean+pet37_grouped_df[pet37_grouped_df.n==N].test_acc_std).max(), color='#000000', linestyle='dashed')
axs[1,2].set_xscale('log')
axs[1,2].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[1,2].set_xlabel(r'$\kappa$')
axs[1,2].set_ylabel('Test accuracy')
axs[1,2].grid()

N = 3441
axs[1,3].set_title(rf'Pet-37 $N={N}$')
axs[1,3].plot(pet37_grouped_df[pet37_grouped_df.n==N].kappa, pet37_grouped_df[pet37_grouped_df.n==N].test_acc_mean, color='#1F77B4')
axs[1,3].fill_between(pet37_grouped_df[pet37_grouped_df.n==N].kappa, pet37_grouped_df[pet37_grouped_df.n==N].test_acc_mean-pet37_grouped_df[pet37_grouped_df.n==N].test_acc_std, pet37_grouped_df[pet37_grouped_df.n==N].test_acc_mean+pet37_grouped_df[pet37_grouped_df.n==N].test_acc_std, alpha=0.1, color='#1F77B4')
axs[1,3].vlines(D/N, (pet37_grouped_df[pet37_grouped_df.n==N].test_acc_mean-pet37_grouped_df[pet37_grouped_df.n==N].test_acc_std).min(), (pet37_grouped_df[pet37_grouped_df.n==N].test_acc_mean+pet37_grouped_df[pet37_grouped_df.n==N].test_acc_std).max(), color='#000000', linestyle='dashed')
axs[1,3].set_xscale('log')
axs[1,3].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[1,3].set_xlabel(r'$\kappa$')
axs[1,3].set_ylabel('Test accuracy')
axs[1,3].grid()

fig.tight_layout()
fig.savefig('convnext_tiny_varying_kappa_acc.pdf', bbox_inches='tight')
plt.show()

# %%
ncols, nrows = 4, 2
fig, axs = plt.subplots(figsize=(4*ncols, 3*nrows), ncols=ncols, nrows=nrows)

D = 27827818
N = 100
axs[0,0].set_title(rf'CIFAR-10 $N={N}$')
axs[0,0].plot(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean, color='#1F77B4')
axs[0,0].fill_between(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std, cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std, alpha=0.1, color='#1F77B4')
axs[0,0].vlines(D/N, (cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std).min(), (cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std).max(), color='#000000', linestyle='dashed')
axs[0,0].set_xscale('log')
axs[0,0].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[0,0].set_xlabel(r'$\kappa$')
axs[0,0].set_ylabel('Test NLL')
axs[0,0].grid()

N = 1000
axs[0,1].set_title(rf'CIFAR-10 $N={N}$')
axs[0,1].plot(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean, color='#1F77B4')
axs[0,1].fill_between(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std, cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std, alpha=0.1, color='#1F77B4')
axs[0,1].vlines(D/N, (cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std).min(), (cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std).max(), color='#000000', linestyle='dashed')
axs[0,1].set_xscale('log')
axs[0,1].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[0,1].set_xlabel(r'$\kappa$')
axs[0,1].set_ylabel('Test NLL')
axs[0,1].grid()

N = 10000
axs[0,2].set_title(rf'CIFAR-10 $N={N}$')
axs[0,2].plot(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean, color='#1F77B4')
axs[0,2].fill_between(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std, cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std, alpha=0.1, color='#1F77B4')
axs[0,2].vlines(D/N, (cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std).min(), (cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std).max(), color='#000000', linestyle='dashed')
axs[0,2].set_xscale('log')
axs[0,2].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[0,2].set_xlabel(r'$\kappa$')
axs[0,2].set_ylabel('Test NLL')
axs[0,2].grid()

N = 50000
axs[0,3].set_title(rf'CIFAR-10 $N={N}$')
axs[0,3].plot(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean, color='#1F77B4')
axs[0,3].fill_between(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std, cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std, alpha=0.1, color='#1F77B4')
axs[0,3].vlines(D/N, (cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std).min(), (cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std).max(), color='#000000', linestyle='dashed')
axs[0,3].set_xscale('log')
axs[0,3].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[0,3].set_xlabel(r'$\kappa$')
axs[0,3].set_ylabel('Test NLL')
axs[0,3].grid()

D = 27898566
N = 510
axs[1,0].set_title(rf'Flower-102 $N={N}$')
axs[1,0].plot(flower102_grouped_df[flower102_grouped_df.n==N].kappa, flower102_grouped_df[flower102_grouped_df.n==N].test_nll_mean, color='#1F77B4', label='iso DE-ELBO (ours)')
axs[1,0].fill_between(flower102_grouped_df[flower102_grouped_df.n==N].kappa, flower102_grouped_df[flower102_grouped_df.n==N].test_nll_mean-flower102_grouped_df[flower102_grouped_df.n==N].test_nll_std, flower102_grouped_df[flower102_grouped_df.n==N].test_nll_mean+flower102_grouped_df[flower102_grouped_df.n==N].test_nll_std, alpha=0.1, color='#1F77B4')
axs[1,0].vlines(D/N, (flower102_grouped_df[flower102_grouped_df.n==N].test_nll_mean-flower102_grouped_df[flower102_grouped_df.n==N].test_nll_std).min(), (flower102_grouped_df[flower102_grouped_df.n==N].test_nll_mean+flower102_grouped_df[flower102_grouped_df.n==N].test_nll_std).max(), color='#000000', linestyle='dashed')
axs[1,0].text(D/N, (1/2) * (flower102_grouped_df[flower102_grouped_df.n==N].test_nll_mean.min() + flower102_grouped_df[flower102_grouped_df.n==N].test_nll_mean.max()), r'$\frac{D}{N}$  ', ha='right', va='center')
axs[1,0].set_xscale('log')
axs[1,0].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[1,0].set_xlabel(r'$\kappa$')
axs[1,0].set_ylabel('Test NLL')
axs[1,0].legend(loc='upper left')
axs[1,0].grid()

N = 1020
axs[1,1].set_title(rf'Flower-102 $N={N}$')
axs[1,1].plot(flower102_grouped_df[flower102_grouped_df.n==N].kappa, flower102_grouped_df[flower102_grouped_df.n==N].test_nll_mean, color='#1F77B4')
axs[1,1].fill_between(flower102_grouped_df[flower102_grouped_df.n==N].kappa, flower102_grouped_df[flower102_grouped_df.n==N].test_nll_mean-flower102_grouped_df[flower102_grouped_df.n==N].test_nll_std, flower102_grouped_df[flower102_grouped_df.n==N].test_nll_mean+flower102_grouped_df[flower102_grouped_df.n==N].test_nll_std, alpha=0.1, color='#1F77B4')
axs[1,1].vlines(D/N, (flower102_grouped_df[flower102_grouped_df.n==N].test_nll_mean-flower102_grouped_df[flower102_grouped_df.n==N].test_nll_std).min(), (flower102_grouped_df[flower102_grouped_df.n==N].test_nll_mean+flower102_grouped_df[flower102_grouped_df.n==N].test_nll_std).max(), color='#000000', linestyle='dashed')
axs[1,1].set_xscale('log')
axs[1,1].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[1,1].set_xlabel(r'$\kappa$')
axs[1,1].set_ylabel('Test NLL')
axs[1,1].grid()

D = 27848581
N = 370
axs[1,2].set_title(rf'Pet-37 $N={N}$')
axs[1,2].plot(pet37_grouped_df[pet37_grouped_df.n==N].kappa, pet37_grouped_df[pet37_grouped_df.n==N].test_nll_mean, color='#1F77B4')
axs[1,2].fill_between(pet37_grouped_df[pet37_grouped_df.n==N].kappa, pet37_grouped_df[pet37_grouped_df.n==N].test_nll_mean-pet37_grouped_df[pet37_grouped_df.n==N].test_nll_std, pet37_grouped_df[pet37_grouped_df.n==N].test_nll_mean+pet37_grouped_df[pet37_grouped_df.n==N].test_nll_std, alpha=0.1, color='#1F77B4')
axs[1,2].vlines(D/N, (pet37_grouped_df[pet37_grouped_df.n==N].test_nll_mean-pet37_grouped_df[pet37_grouped_df.n==N].test_nll_std).min(), (pet37_grouped_df[pet37_grouped_df.n==N].test_nll_mean+pet37_grouped_df[pet37_grouped_df.n==N].test_nll_std).max(), color='#000000', linestyle='dashed')
axs[1,2].set_xscale('log')
axs[1,2].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[1,2].set_xlabel(r'$\kappa$')
axs[1,2].set_ylabel('Test NLL')
axs[1,2].grid()

N = 3441
axs[1,3].set_title(rf'Pet-37 $N={N}$')
axs[1,3].plot(pet37_grouped_df[pet37_grouped_df.n==N].kappa, pet37_grouped_df[pet37_grouped_df.n==N].test_nll_mean, color='#1F77B4')
axs[1,3].fill_between(pet37_grouped_df[pet37_grouped_df.n==N].kappa, pet37_grouped_df[pet37_grouped_df.n==N].test_nll_mean-pet37_grouped_df[pet37_grouped_df.n==N].test_nll_std, pet37_grouped_df[pet37_grouped_df.n==N].test_nll_mean+pet37_grouped_df[pet37_grouped_df.n==N].test_nll_std, alpha=0.1, color='#1F77B4')
axs[1,3].vlines(D/N, (pet37_grouped_df[pet37_grouped_df.n==N].test_nll_mean-pet37_grouped_df[pet37_grouped_df.n==N].test_nll_std).min(), (pet37_grouped_df[pet37_grouped_df.n==N].test_nll_mean+pet37_grouped_df[pet37_grouped_df.n==N].test_nll_std).max(), color='#000000', linestyle='dashed')
axs[1,3].set_xscale('log')
axs[1,3].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[1,3].set_xlabel(r'$\kappa$')
axs[1,3].set_ylabel('Test NLL')
axs[1,3].grid()

fig.tight_layout()
fig.savefig('convnext_tiny_varying_kappa_nll.pdf', bbox_inches='tight')
plt.show()

# %%
ncols, nrows = 2, 1
fig, axs = plt.subplots(figsize=(4*ncols, 3*nrows), ncols=ncols, nrows=nrows)

D = 27827818
N = 50000

#axs[0].set_title(rf'CIFAR-10 $N={N}$ (ConvNeXt-Tiny)')
axs[0].plot(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean, color='#1F77B4', label=r'$q, \eta$ trained w/ DE-ELBO (ours)', linewidth=3)
axs[0].fill_between(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std, cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std, alpha=0.1, color='#1F77B4', linewidth=3)
axs[0].vlines(D/N, (cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std).min(), (cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_std).max(), color='#000000', linestyle='dashed', linewidth=3)
axs[0].text(D/N, (1/2) * (cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean.min() + cifar10_grouped_df[cifar10_grouped_df.n==N].test_acc_mean.max()), r"$\frac{D}{N}$  ", ha='right', va='center', fontsize=11)
axs[0].set_xscale('log')
axs[0].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[0].set_xlabel(r'$\kappa$')
axs[0].set_ylabel('Test accuracy')
axs[0].legend(loc='lower right')
axs[0].grid()

#axs[1].set_title(rf'CIFAR-10 $N={N}$ (ConvNeXt-Tiny)')
axs[1].plot(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean, color='#1F77B4', linewidth=3)
axs[1].fill_between(cifar10_grouped_df[cifar10_grouped_df.n==N].kappa, cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std, cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std, alpha=0.1, color='#1F77B4', linewidth=3)
axs[1].vlines(D/N, (cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean-cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std).min(), (cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_mean+cifar10_grouped_df[cifar10_grouped_df.n==N].test_nll_std).max(), color='#000000', linestyle='dashed', linewidth=3)
axs[1].set_xscale('log')
axs[1].yaxis.set_major_formatter(ticker.FormatStrFormatter('%.2f'))
axs[1].set_xlabel(r'$\kappa$')
axs[1].set_ylabel('Test NLL')
axs[1].grid()

fig.tight_layout()
fig.savefig('convnext_tiny_varying_kappa.pdf', bbox_inches='tight')
plt.show()

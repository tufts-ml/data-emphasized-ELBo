# %%
import os
import math
import itertools
import numpy as np

import pandas as pd

# %%
def check_epochs(df, n, batch_size=128, drop_last=True, steps=6000):
    num_batches = math.floor(n/batch_size) if drop_last else math.ceil(n/batch_size)
    epochs = int(steps/num_batches)
    return True if df.shape[0] == epochs else False

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/AG_News'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_AG_News_SGD'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [40, 400, 4_000, 40_000, 120_000]
ns = [40]
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        n_train = n - int((1/5) * n)
        if not check_epochs(temp_df, n_train, batch_size=min(32, n_train), drop_last=False, steps=12_000):
            count += 1
            print(f'    "python ../src/fine-tuning_AG_News.py --alpha={alpha} --batch_size=32 --beta={beta} --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/fine-tuning_AG_News.py --alpha={alpha} --batch_size=32 --beta={beta} --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/AG_News'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_AG_News_SGD'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [40, 400, 4_000, 40_000, 120_000]
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(32, n), steps=12_000, drop_last=False):
            count += 1
            print(f'    "python ../src/fine-tuning_AG_News.py --alpha={alpha} --batch_size=32 --beta={beta} --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --save"')
    else:
        count += 1
        print(f'    "python ../src/fine-tuning_AG_News.py --alpha={alpha} --batch_size=32 --beta={beta} --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --save"')
print(count)
# Out:
# -1

# %%
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/AG_News'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_AG_News_VI_SGD'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [40, 400, 4_000, 40_000, 120_000]
random_states = [1001, 2001, 3001]

count = -1
for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa=1.0_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(32, n), drop_last=False, steps=12_000):
            count += 1
            print(f'    "python ../src/fine-tuning_AG_News_VI.py --batch_size=32 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa=1.0 --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --save"')
    else:
        count += 1
        print(f'    "python ../src/fine-tuning_AG_News_VI.py --batch_size=32 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa=1.0 --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --save"')
print(count)
# Out:
#     "python ../src/fine-tuning_AG_News_VI.py --batch_size=32 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/AG_News' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_AG_News_VI_SGD' --kappa=1.0 --lr_0=0.1 --model_name='l2-sp_kappa=1.0_lr_0=0.1_n=40_random_state=1001' --n=40 --num_workers=0 --random_state=1001 --save"
#     "python ../src/fine-tuning_AG_News_VI.py --batch_size=32 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/AG_News' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_AG_News_VI_SGD' --kappa=1.0 --lr_0=0.1 --model_name='l2-sp_kappa=1.0_lr_0=0.1_n=40_random_state=2001' --n=40 --num_workers=0 --random_state=2001 --save"
# ...

# %%
criterion = 'l2-sp'
d = 109_485_316
dataset_directory = '/cluster/tufts/hugheslab/eharve06/AG_News'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_AG_News_VI_SGD'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [40, 400, 4_000, 40_000, 120_000]
ns = [40, 400, 4_000, 40_000]
random_states = [1001, 2001, 3001]

count = -1
for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={d/n}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(32, n), drop_last=False, steps=12_000):
            count += 1
            print(f'    "python ../src/fine-tuning_AG_News_VI.py --batch_size=32 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={d/n} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --save"')
    else:
        count += 1
        print(f'    "python ../src/fine-tuning_AG_News_VI.py --batch_size=32 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --ELBo --experiments_directory=\'{experiments_directory}\' --kappa={d/n} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --save"')
print(count)
# Out:
#     "python ../src/fine-tuning_AG_News_VI.py --batch_size=32 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/AG_News' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_AG_News_VI_SGD' --kappa=2737132.9 --lr_0=0.1 --model_name='l2-sp_kappa=2737132.9_lr_0=0.1_n=40_random_state=1001' --n=40 --num_workers=0 --random_state=1001 --save"
#     "python ../src/fine-tuning_AG_News_VI.py --batch_size=32 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/AG_News' --ELBo --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_AG_News_VI_SGD' --kappa=2737132.9 --lr_0=0.1 --model_name='l2-sp_kappa=2737132.9_lr_0=0.1_n=40_random_state=2001' --n=40 --num_workers=0 --random_state=2001 --save"
# ...

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/tuned_AG_News'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_AG_News_SGD'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [40, 400, 4_000, 40_000, 120_000]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'runtime', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df['train_sec/epoch'].sum(), temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        tuned_df.loc[len(tuned_df)] = row

min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_AG_News_SGD'

columns = ['criterion', 'model_name', 'n', 'random_state', 'runtime', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df['train_sec/epoch'].sum(), temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row

retrained_df
# Out:
#    criterion                                         model_name       n  \
# 0      l2-sp  l2-sp_alpha=0.0001_beta=0.001_lr_0=0.1_n=40_ra...      40
# 1      l2-sp  l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=40_rand...      40
# 2      l2-sp  l2-sp_alpha=1e-05_beta=0.0001_lr_0=0.1_n=40_ra...      40
# 3      l2-sp  l2-sp_alpha=0.01_beta=0.01_lr_0=0.0001_n=400_r...     400
# 4      l2-sp  l2-sp_alpha=0.01_beta=0.01_lr_0=0.0001_n=400_r...     400
# 5      l2-sp  l2-sp_alpha=0.001_beta=0.0_lr_0=0.1_n=400_rand...     400
# 6      l2-sp  l2-sp_alpha=0.0_beta=0.01_lr_0=0.0001_n=4000_r...    4000
# 7      l2-sp  l2-sp_alpha=0.001_beta=0.01_lr_0=0.0001_n=4000...    4000
# 8      l2-sp  l2-sp_alpha=0.0_beta=0.01_lr_0=0.0001_n=4000_r...    4000
# 9      l2-sp  l2-sp_alpha=0.0001_beta=0.001_lr_0=0.001_n=400...   40000
# 10     l2-sp  l2-sp_alpha=0.01_beta=1e-06_lr_0=0.1_n=40000_r...   40000
# 11     l2-sp  l2-sp_alpha=1e-06_beta=0.01_lr_0=0.001_n=40000...   40000
# ...

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion       n                                         model_name  \
# 0     l2-sp      40  (l2-sp_alpha=0.0001_beta=0.001_lr_0=0.1_n=40_r...
# 1     l2-sp     400  (l2-sp_alpha=0.01_beta=0.01_lr_0=0.0001_n=400_...
# 2     l2-sp    4000  (l2-sp_alpha=0.0_beta=0.01_lr_0=0.0001_n=4000_...
# 3     l2-sp   40000  (l2-sp_alpha=0.0001_beta=0.001_lr_0=0.001_n=40...
# 4     l2-sp  120000  (l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=120000...
#
#          random_state                                            runtime  \
# 0  (1001, 2001, 3001)  (4939.043723344803, 4819.914232969284, 4879.56...
# 1  (1001, 2001, 3001)  (7619.886640787125, 7469.472638845444, 7303.15...
# 2  (1001, 2001, 3001)  (7670.42826128006, 7707.774529457092, 7645.275...
# 3  (1001, 2001, 3001)  (7275.033919095993, 7093.371614694595, 7399.47...
# 4  (1001, 2001, 3001)  (7171.257834196091, 7052.336588859558, 6877.64...
#
#                                             test_acc  \
# ...

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion       n  test_acc_mean  test_acc_min  test_acc_max
# 0     l2-sp      40       0.627368      0.250000      0.818816
# 1     l2-sp     400       0.850614      0.837632      0.870132
# 2     l2-sp    4000       0.894430      0.893026      0.895921
# 3     l2-sp   40000       0.924079      0.918684      0.928158
# 4     l2-sp  120000       0.933640      0.921974      0.940000

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion       n  test_nll_mean  test_nll_min  test_nll_max
# 0     l2-sp      40       0.120071      0.108664      0.130245
# 1     l2-sp     400       0.092870      0.052812      0.167062
# 2     l2-sp    4000       0.031124      0.030609      0.031632
# 3     l2-sp   40000       0.021908      0.020771      0.024162
# 4     l2-sp  120000       0.018595      0.016894      0.021661

# %%
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/AG_News'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_AG_News_diagEF_F=1_SGD'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [120_000]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'train_log_marglik', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df.train_log_marglik.values[-1], temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row

retrained_df
# Out:
#    criterion                                    model_name       n  \
# 0      l2-sp     l2-sp_lr_0=0.1_n=120000_random_state=1001  120000
# 1      l2-sp     l2-sp_lr_0=0.1_n=120000_random_state=2001  120000
# 2      l2-sp     l2-sp_lr_0=0.1_n=120000_random_state=3001  120000
# 3      l2-sp    l2-sp_lr_0=0.01_n=120000_random_state=1001  120000
# 4      l2-sp    l2-sp_lr_0=0.01_n=120000_random_state=2001  120000
# 5      l2-sp    l2-sp_lr_0=0.01_n=120000_random_state=3001  120000
# 6      l2-sp   l2-sp_lr_0=0.001_n=120000_random_state=1001  120000
# 7      l2-sp   l2-sp_lr_0=0.001_n=120000_random_state=2001  120000
# 8      l2-sp   l2-sp_lr_0=0.001_n=120000_random_state=3001  120000
# 9      l2-sp  l2-sp_lr_0=0.0001_n=120000_random_state=1001  120000
# 10     l2-sp  l2-sp_lr_0=0.0001_n=120000_random_state=2001  120000
# 11     l2-sp  l2-sp_lr_0=0.0001_n=120000_random_state=3001  120000
#
#     random_state  train_log_marglik  test_acc  test_nll
# ...

# %%
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/AG_News'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_AG_News_diagEF_F=1_SGD'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [40, 400, 4_000, 40_000, 120_000]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'train_log_marglik', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df.train_log_marglik.values[-1], temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row
    
min_indices = retrained_df.groupby(['criterion', 'n', 'random_state'])['train_log_marglik'].idxmax()
retrained_df = retrained_df.loc[min_indices]

retrained_df
# Out:
#    criterion                                   model_name       n  \
# 15     l2-sp       l2-sp_lr_0=0.01_n=40_random_state=1001      40
# 1      l2-sp        l2-sp_lr_0=0.1_n=40_random_state=2001      40
# 17     l2-sp       l2-sp_lr_0=0.01_n=40_random_state=3001      40
# 33     l2-sp     l2-sp_lr_0=0.001_n=400_random_state=1001     400
# 34     l2-sp     l2-sp_lr_0=0.001_n=400_random_state=2001     400
# 35     l2-sp     l2-sp_lr_0=0.001_n=400_random_state=3001     400
# 6      l2-sp      l2-sp_lr_0=0.1_n=4000_random_state=1001    4000
# 7      l2-sp      l2-sp_lr_0=0.1_n=4000_random_state=2001    4000
# 8      l2-sp      l2-sp_lr_0=0.1_n=4000_random_state=3001    4000
# 24     l2-sp    l2-sp_lr_0=0.01_n=40000_random_state=1001   40000
# 25     l2-sp    l2-sp_lr_0=0.01_n=40000_random_state=2001   40000
# 26     l2-sp    l2-sp_lr_0=0.01_n=40000_random_state=3001   40000
# 42     l2-sp  l2-sp_lr_0=0.001_n=120000_random_state=1001  120000
# ...

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion       n                                         model_name  \
# 0     l2-sp      40  (l2-sp_lr_0=0.01_n=40_random_state=1001, l2-sp...
# 1     l2-sp     400  (l2-sp_lr_0=0.001_n=400_random_state=1001, l2-...
# 2     l2-sp    4000  (l2-sp_lr_0=0.1_n=4000_random_state=1001, l2-s...
# 3     l2-sp   40000  (l2-sp_lr_0=0.01_n=40000_random_state=1001, l2...
# 4     l2-sp  120000  (l2-sp_lr_0=0.001_n=120000_random_state=1001, ...
#
#          random_state                                  train_log_marglik  \
# 0  (1001, 2001, 3001)  (-55.45175552368164, -55.45176696777344, -55.4...
# 1  (1001, 2001, 3001)  (-21.585281372070312, -2.197819471359253, -2.5...
# 2  (1001, 2001, 3001)  (-1516.1123046875, -1808.2838134765625, -1578....
# 3  (1001, 2001, 3001)  (-12451.97265625, -12221.880859375, -12216.539...
# 4  (1001, 2001, 3001)  (-33719.6171875, -34533.69140625, -33300.94921...
#
#                                             test_acc  \
# ...

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion       n  test_acc_mean  test_acc_min  test_acc_max
# 0     l2-sp      40       0.270175      0.262237      0.274737
# 1     l2-sp     400       0.841930      0.835263      0.853421
# 2     l2-sp    4000       0.898026      0.896711      0.900263
# 3     l2-sp   40000       0.931184      0.929868      0.933816
# 4     l2-sp  120000       0.925351      0.924868      0.926053

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion       n  test_nll_mean  test_nll_min  test_nll_max
# 0     l2-sp      40       0.130239      0.130239      0.130239
# 1     l2-sp     400       0.084781      0.080846      0.088624
# 2     l2-sp    4000       0.029513      0.029222      0.029964
# 3     l2-sp   40000       0.020002      0.019699      0.020519
# 4     l2-sp  120000       0.020989      0.020914      0.021052

# %%
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/AG_News'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_AG_News_VI_SGD'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [40, 400, 4_000, 40_000, 120_000]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'train_loss', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa=1.0_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df.train_loss.values[-1], temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row
    
min_indices = retrained_df.groupby(['criterion', 'n', 'random_state'])['train_loss'].idxmin()
retrained_df = retrained_df.loc[min_indices]

retrained_df
# Out:
#    criterion                                         model_name       n  \
# 30     l2-sp  l2-sp_kappa=1.0_lr_0=0.001_n=40_random_state=1001      40
# 16     l2-sp   l2-sp_kappa=1.0_lr_0=0.01_n=40_random_state=2001      40
# 47     l2-sp  l2-sp_kappa=1.0_lr_0=0.0001_n=40_random_state=...      40
# 33     l2-sp  l2-sp_kappa=1.0_lr_0=0.001_n=400_random_state=...     400
# 49     l2-sp  l2-sp_kappa=1.0_lr_0=0.0001_n=400_random_state...     400
# 35     l2-sp  l2-sp_kappa=1.0_lr_0=0.001_n=400_random_state=...     400
# 21     l2-sp  l2-sp_kappa=1.0_lr_0=0.01_n=4000_random_state=...    4000
# 22     l2-sp  l2-sp_kappa=1.0_lr_0=0.01_n=4000_random_state=...    4000
# 23     l2-sp  l2-sp_kappa=1.0_lr_0=0.01_n=4000_random_state=...    4000
# 24     l2-sp  l2-sp_kappa=1.0_lr_0=0.01_n=40000_random_state...   40000
# 25     l2-sp  l2-sp_kappa=1.0_lr_0=0.01_n=40000_random_state...   40000
# 26     l2-sp  l2-sp_kappa=1.0_lr_0=0.01_n=40000_random_state...   40000
# ...

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion       n                                         model_name  \
# 0     l2-sp      40  (l2-sp_kappa=1.0_lr_0=0.001_n=40_random_state=...
# 1     l2-sp     400  (l2-sp_kappa=1.0_lr_0=0.001_n=400_random_state...
# 2     l2-sp    4000  (l2-sp_kappa=1.0_lr_0=0.01_n=4000_random_state...
# 3     l2-sp   40000  (l2-sp_kappa=1.0_lr_0=0.01_n=40000_random_stat...
# 4     l2-sp  120000  (l2-sp_kappa=1.0_lr_0=0.01_n=120000_random_sta...
#
#          random_state                                         train_loss  \
# 0  (1001, 2001, 3001)  (0.2079354724287986, 0.2076700124144554, 0.207...
# 1  (1001, 2001, 3001)  (0.1351608737111091, 0.1351701433360576, 0.135...
# 2  (1001, 2001, 3001)  (0.0660866616904735, 0.0692214154466986, 0.067...
# 3  (1001, 2001, 3001)  (0.0411162489674985, 0.0412603383306786, 0.040...
# 4  (1001, 2001, 3001)  (0.0348395928038097, 0.0348225530836731, 0.034...
#
#                                             test_acc  \
# ...

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion       n  test_acc_mean  test_acc_min  test_acc_max
# 0     l2-sp      40       0.272456      0.261711      0.290921
# 1     l2-sp     400       0.297061      0.258158      0.334605
# 2     l2-sp    4000       0.865351      0.851974      0.874079
# 3     l2-sp   40000       0.903377      0.899868      0.906447
# 4     l2-sp  120000       0.907588      0.906053      0.909079

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion       n  test_nll_mean  test_nll_min  test_nll_max
# 0     l2-sp      40       0.130235      0.130227      0.130239
# 1     l2-sp     400       0.130238      0.130238      0.130238
# 2     l2-sp    4000       0.039709      0.038918      0.040973
# 3     l2-sp   40000       0.028086      0.027421      0.028546
# 4     l2-sp  120000       0.025475      0.025047      0.026242

# %%
criterion = 'l2-sp'
d = 109_485_316
dataset_directory = '/cluster/tufts/hugheslab/eharve06/AG_News'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/retrained_AG_News_VI_SGD'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [40, 400, 4_000, 40_000, 120_000]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'train_loss', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for lr_0, n, random_state in itertools.product(lr_0s, ns, random_states):
    model_name = f'{criterion}_kappa={d/n}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df.train_loss.values[-1], temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row
    
min_indices = retrained_df.groupby(['criterion', 'n', 'random_state'])['train_loss'].idxmin()
retrained_df = retrained_df.loc[min_indices]

retrained_df
# Out:
#    criterion                                         model_name       n  \
# 15     l2-sp  l2-sp_kappa=2737132.9_lr_0=0.01_n=40_random_st...      40
# 16     l2-sp  l2-sp_kappa=2737132.9_lr_0=0.01_n=40_random_st...      40
# 17     l2-sp  l2-sp_kappa=2737132.9_lr_0=0.01_n=40_random_st...      40
# 18     l2-sp  l2-sp_kappa=273713.29_lr_0=0.01_n=400_random_s...     400
# 19     l2-sp  l2-sp_kappa=273713.29_lr_0=0.01_n=400_random_s...     400
# 20     l2-sp  l2-sp_kappa=273713.29_lr_0=0.01_n=400_random_s...     400
# 21     l2-sp  l2-sp_kappa=27371.329_lr_0=0.01_n=4000_random_...    4000
# 22     l2-sp  l2-sp_kappa=27371.329_lr_0=0.01_n=4000_random_...    4000
# 23     l2-sp  l2-sp_kappa=27371.329_lr_0=0.01_n=4000_random_...    4000
# 24     l2-sp  l2-sp_kappa=2737.1329_lr_0=0.01_n=40000_random...   40000
# 25     l2-sp  l2-sp_kappa=2737.1329_lr_0=0.01_n=40000_random...   40000
# 26     l2-sp  l2-sp_kappa=2737.1329_lr_0=0.01_n=40000_random...   40000
# ...

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion       n                                         model_name  \
# 0     l2-sp      40  (l2-sp_kappa=2737132.9_lr_0=0.01_n=40_random_s...
# 1     l2-sp     400  (l2-sp_kappa=273713.29_lr_0=0.01_n=400_random_...
# 2     l2-sp    4000  (l2-sp_kappa=27371.329_lr_0=0.01_n=4000_random...
# 3     l2-sp   40000  (l2-sp_kappa=2737.1329_lr_0=0.01_n=40000_rando...
# 4     l2-sp  120000  (l2-sp_kappa=912.3776333333333_lr_0=0.01_n=120...
#
#          random_state                                         train_loss  \
# 0  (1001, 2001, 3001)  (5.953353815129958e-05, 6.250071724934968e-05,...
# 1  (1001, 2001, 3001)  (4.457928298506886e-05, 4.458525598602136e-05,...
# 2  (1001, 2001, 3001)  (0.0001113005944469, 0.0001071655002393, 0.000...
# 3  (1001, 2001, 3001)  (0.0042273585478076, 0.0047640239867032, 0.004...
# 4  (1001, 2001, 3001)  (0.0116779344707843, 0.0116871070085233, 0.011...
#
#                                             test_acc  \
# ...

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion       n  test_acc_mean  test_acc_min  test_acc_max
# 0     l2-sp      40       0.744298      0.726974      0.754737
# 1     l2-sp     400       0.877500      0.874342      0.881710
# 2     l2-sp    4000       0.911096      0.909211      0.912105
# 3     l2-sp   40000       0.935395      0.934079      0.936184
# 4     l2-sp  120000       0.944167      0.943158      0.944737

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion       n  test_nll_mean  test_nll_min  test_nll_max
# 0     l2-sp      40       0.170712      0.156304      0.185482
# 1     l2-sp     400       0.103211      0.097148      0.106823
# 2     l2-sp    4000       0.084205      0.083181      0.085788
# 3     l2-sp   40000       0.027049      0.026630      0.027526
# 4     l2-sp  120000       0.016503      0.016397      0.016708

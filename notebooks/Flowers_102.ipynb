# %%
import os
import math
import itertools
import numpy as np
import pandas as pd

# %%
def check_epochs(df, n, batch_size=128, steps=6000):
    num_batches = math.floor(n/batch_size)
    epochs = int(steps/num_batches)
    if df.shape[0] == epochs:
        return True
    else:
        return False

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-zero'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Flowers_102'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

count = -1
for alpha, lr_0, n, random_state in itertools.product(alphas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
print(count)
# Out:
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.001_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.001_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.001_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.001_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.001_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.001_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.001_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.001_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.001_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.001_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.001_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.001_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.001_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.001_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.001_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.001_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.001_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.001_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.001_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.001_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.001_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.001_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.001_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.001_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.0001_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.0001_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.0001_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.0001_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.0001_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.0001_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.0001_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.0001_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.0001_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.0001_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.0001_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.0001_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.0001_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.0001_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.0001_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.0001_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.0001_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.0001_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.0001_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.0001_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.0001_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.0001_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.0001_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0001 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.0001_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=1e-05_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=1e-05_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=1e-05_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=1e-05_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=1e-05_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=1e-05_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=1e-05_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=1e-05_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=1e-05_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=1e-05_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=1e-05_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=1e-05_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=1e-05_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=1e-05_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=1e-05_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=1e-05_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=1e-05_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=1e-05_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=1e-05_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=1e-05_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=1e-05_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=1e-05_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=1e-05_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-05 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=1e-05_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=1e-06_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=1e-06_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=1e-06_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=1e-06_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=1e-06_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=1e-06_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=1e-06_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=1e-06_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=1e-06_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=1e-06_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=1e-06_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=1e-06_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=1e-06_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=1e-06_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=1e-06_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=1e-06_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=1e-06_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=1e-06_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=1e-06_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=1e-06_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=1e-06_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=1e-06_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=1e-06_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=1e-06 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=1e-06_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-zero_alpha=0.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-zero_alpha=0.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-zero_alpha=0.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --batch_size=128 --criterion='l2-zero' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-zero_alpha=0.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
# 119

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Flowers_102'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
print(count)
# Out:
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.01 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.01_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.001_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=0.0001 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=0.0001_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-05 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.01_beta=1e-05_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.01 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.01_beta=1e-06_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
# ...
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=1e-06 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.0_beta=1e-06_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.1 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.01 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.001 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --alpha=0.0 --beta=0.0 --batch_size=128 --criterion='l2-sp' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lr_0=0.0001 --model_name='l2-sp_alpha=0.0_beta=0.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
# 863

# %%
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'ptyl'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Flowers_102'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL'
lambds = np.logspace(start=0, stop=9, num=10)
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
prior_directory = '/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior'
prior_type = 'resnet50_ssl_prior'
random_states = [1001, 2001, 3001]

count = -1
for beta, lambd, lr_0, n, random_state in itertools.product(betas, lambds, lr_0s, ns, random_states):
    model_name = f'{criterion}_beta={beta}_lambd={lambd}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lambd={lambd} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lambd={lambd} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune"')
print(count)
# Out:
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
# ...
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='/cluster/tufts/hugheslab/eharve06/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
# 1439

# %%
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'ptyl'
dataset_directory = '/cluster/tufts/hugheslab/eharve06/Flowers_102'
experiments_directory = '/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102'
lambds = np.logspace(start=0, stop=9, num=10)
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

count = -1
for beta, lambd, lr_0, n, random_state in itertools.product(betas, lambds, lr_0s, ns, random_states):
    model_name = f'{criterion}_beta={beta}_lambd={lambd}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lambd={lambd} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lambd={lambd} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
print(count)
# Out:
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=10.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1000.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=10000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=10000.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
# ...
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=100000000.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.0 --batch_size=128 --criterion='ptyl' --dataset_directory='/cluster/tufts/hugheslab/eharve06/Flowers_102' --experiments_directory='/cluster/tufts/hugheslab/eharve06/data-emphasized-ELBo/experiments/tuned_Flowers_102' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.0_lambd=1000000000.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --random_state=3001 --tune"
# 1439

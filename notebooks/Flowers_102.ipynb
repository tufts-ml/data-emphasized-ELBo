# %%
import os
import math
import itertools
import numpy as np
import pandas as pd

# %%
def check_epochs(df, n, batch_size=128, steps=6000):
    num_batches = math.floor(n/batch_size)
    epochs = int(steps/num_batches)
    if df.shape[0] == epochs:
        return True
    else:
        return False

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-zero'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

count = -1
for alpha, lr_0, n, random_state in itertools.product(alphas, lr_0s, ns, random_states):
    model_name = f'linear_probing_alpha={alpha}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-zero'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

count = -1
for alpha, lr_0, n, random_state in itertools.product(alphas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
print(count)
# Out:
# -1

# %%
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'ptyl'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL'
lambds = np.logspace(start=0, stop=9, num=10)
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
prior_directory = '{home_dir}/resnet50_ssl_prior'
prior_type = 'resnet50_ssl_prior'
random_states = [1001, 2001, 3001]

count = -1
for beta, lambd, lr_0, n, random_state in itertools.product(betas, lambds, lr_0s, ns, random_states):
    model_name = f'{criterion}_beta={beta}_lambd={lambd}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lambd={lambd} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lambd={lambd} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune"')
print(count)
# Out:
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=100000000.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.01 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.01_lambd=1000000000.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=1.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=10.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=10.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=100.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=100.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=100.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=100.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=100.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=100.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=100.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=100.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=100.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=100.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=100.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=100.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=100.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=100.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
# ...
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.0001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.0001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.0001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.0001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.0001_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=100000.0 --lr_0=0.0001 --model_name='ptyl_beta=0.001_lambd=100000.0_lr_0=0.0001_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.1_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.1_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.1_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.1_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.1_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.1 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.1_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.01_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.01_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.01_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.01_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.01_n=1020_random_state=2001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.01 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.01_n=1020_random_state=3001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.001_n=510_random_state=1001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.001_n=510_random_state=2001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=2001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.001_n=510_random_state=3001' --n=510 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=3001 --tune"
#     "python ../src/main_Flowers_102.py --beta=0.001 --batch_size=128 --criterion='ptyl' --dataset_directory='{home_dir}/Flowers_102' --experiments_directory='{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL' --lambd=1000000.0 --lr_0=0.001 --model_name='ptyl_beta=0.001_lambd=1000000.0_lr_0=0.001_n=1020_random_state=1001' --n=1020 --num_workers=0 --prior_directory='{home_dir}/resnet50_ssl_prior' --prior_type='resnet50_ssl_prior' --random_state=1001 --tune"
# 199

# %%
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'ptyl'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102'
lambds = np.logspace(start=0, stop=9, num=10)
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

count = -1
for beta, lambd, lr_0, n, random_state in itertools.product(betas, lambds, lr_0s, ns, random_states):
    model_name = f'{criterion}_beta={beta}_lambd={lambd}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lambd={lambd} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lambd={lambd} --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state} --tune"')
print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_ViT_B_16'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
model_arch = 'ViT-B/16'
ns = [510, 1020]
prior_directory = '{home_dir}/vit_b_16_torchvision'
prior_type = 'vit_b_16_torchvision'
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune"')
print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_ConvNeXt_Tiny'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
model_arch = 'ConvNeXt_Tiny'
ns = [510, 1020]
prior_directory = '{home_dir}/convnext_tiny_torchvision'
prior_type = 'convnext_tiny_torchvision'
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        tuned_n = n - int((1/5) * n)
        if not check_epochs(temp_df, tuned_n, batch_size=min(128, tuned_n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state} --tune"')
print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'linear_probing'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

for alpha, lr_0, n, random_state in itertools.product(alphas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_lr_0={lr_0}_n={n}_random_state={random_state}'
    temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
    row = [criterion, model_name, n, random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
    tuned_df.loc[len(tuned_df)] = row
    
min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/retrained_Flowers_102'

columns = ['criterion', 'model_name', 'n', 'random_state', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row

retrained_df
# Out:
#         criterion                                         model_name     n  \
# 0  linear_probing  linear_probing_alpha=0.0_lr_0=0.1_n=510_random...   510
# 1  linear_probing  linear_probing_alpha=1e-05_lr_0=0.1_n=510_rand...   510
# 2  linear_probing  linear_probing_alpha=0.0001_lr_0=0.1_n=510_ran...   510
# 3  linear_probing  linear_probing_alpha=0.0001_lr_0=0.1_n=1020_ra...  1020
# 4  linear_probing  linear_probing_alpha=0.0001_lr_0=0.1_n=1020_ra...  1020
# 5  linear_probing  linear_probing_alpha=0.0001_lr_0=0.1_n=1020_ra...  1020
#
#    random_state  test_acc  test_nll
# 0          1001  0.794731  0.864902
# 1          2001  0.814897  0.812155
# 2          3001  0.809504  0.819738
# 3          1001  0.881106  0.533910
# 4          2001  0.878596  0.533456
# 5          3001  0.878669  0.531358

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#         criterion     n                                         model_name  \
# 0  linear_probing   510  (linear_probing_alpha=0.0_lr_0=0.1_n=510_rando...
# 1  linear_probing  1020  (linear_probing_alpha=0.0001_lr_0=0.1_n=1020_r...
#
#          random_state                                           test_acc  \
# 0  (1001, 2001, 3001)  (0.7947314977645874, 0.8148971796035767, 0.809...
# 1  (1001, 2001, 3001)  (0.881105899810791, 0.878596305847168, 0.87866...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.8649024938509304, 0.812154893139503, 0.8197...       0.806378
# 1  (0.5339101786272512, 0.5334558038155803, 0.531...       0.879457
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.008524      0.794731      0.814897       0.832265      0.023285
# 1      0.001166      0.878596      0.881106       0.532908      0.001112
#
#    test_nll_min  test_nll_max
# 0      0.812155      0.864902
# 1      0.531358      0.533910

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#         criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0  linear_probing   510       0.806378      0.794731      0.814897
# 1  linear_probing  1020       0.879457      0.878596      0.881106

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#         criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0  linear_probing   510       0.832265      0.812155      0.864902
# 1  linear_probing  1020       0.532908      0.531358      0.533910

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-zero'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

for alpha, lr_0, n, random_state in itertools.product(alphas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_lr_0={lr_0}_n={n}_random_state={random_state}'
    temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
    row = [criterion, model_name, n, random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
    tuned_df.loc[len(tuned_df)] = row
    
min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/retrained_Flowers_102'

columns = ['criterion', 'model_name', 'n', 'random_state', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row

retrained_df
# Out:
#   criterion                                         model_name     n  \
# 0   l2-zero  l2-zero_alpha=0.0_lr_0=0.1_n=510_random_state=...   510
# 1   l2-zero  l2-zero_alpha=1e-05_lr_0=0.1_n=510_random_stat...   510
# 2   l2-zero  l2-zero_alpha=1e-05_lr_0=0.1_n=510_random_stat...   510
# 3   l2-zero  l2-zero_alpha=1e-06_lr_0=0.1_n=1020_random_sta...  1020
# 4   l2-zero  l2-zero_alpha=1e-06_lr_0=0.1_n=1020_random_sta...  1020
# 5   l2-zero  l2-zero_alpha=0.0001_lr_0=0.1_n=1020_random_st...  1020
#
#    random_state  test_acc  test_nll
# 0          1001  0.859594  0.675128
# 1          2001  0.865044  0.631728
# 2          3001  0.866699  0.631672
# 3          1001  0.923864  0.380184
# 4          2001  0.927144  0.347217
# 5          3001  0.932412  0.322754

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0   l2-zero   510  (l2-zero_alpha=0.0_lr_0=0.1_n=510_random_state...
# 1   l2-zero  1020  (l2-zero_alpha=1e-06_lr_0=0.1_n=1020_random_st...
#
#          random_state                                           test_acc  \
# 0  (1001, 2001, 3001)  (0.8595935106277466, 0.8650438189506531, 0.866...
# 1  (1001, 2001, 3001)  (0.9238643050193788, 0.9271442294120787, 0.932...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.6751280320207529, 0.6317284799010232, 0.631...       0.863779
# 1  (0.3801838651372868, 0.3472168642901048, 0.322...       0.927807
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.003036      0.859594      0.866699       0.646176      0.020472
# 1      0.003521      0.923864      0.932412       0.350052      0.023531
#
#    test_nll_min  test_nll_max
# 0      0.631672      0.675128
# 1      0.322754      0.380184

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0   l2-zero   510       0.863779      0.859594      0.866699
# 1   l2-zero  1020       0.927807      0.923864      0.932412

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0   l2-zero   510       0.646176      0.631672      0.675128
# 1   l2-zero  1020       0.350052      0.322754      0.380184

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/retrained_Flowers_102'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(128, n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state}"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_name=\'{model_name}\' --n={n} --num_workers=0 --random_state={random_state}"')

print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
    row = [criterion, model_name, n, random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
    tuned_df.loc[len(tuned_df)] = row
    
min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/retrained_Flowers_102'

columns = ['criterion', 'model_name', 'n', 'random_state', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row

retrained_df
# Out:
#   criterion                                         model_name     n  \
# 0     l2-sp  l2-sp_alpha=1e-06_beta=1e-06_lr_0=0.1_n=510_ra...   510
# 1     l2-sp  l2-sp_alpha=0.0_beta=0.0_lr_0=0.1_n=510_random...   510
# 2     l2-sp  l2-sp_alpha=0.0001_beta=0.0_lr_0=0.1_n=510_ran...   510
# 3     l2-sp  l2-sp_alpha=0.0_beta=0.0_lr_0=0.1_n=1020_rando...  1020
# 4     l2-sp  l2-sp_alpha=0.0_beta=1e-05_lr_0=0.1_n=1020_ran...  1020
# 5     l2-sp  l2-sp_alpha=1e-05_beta=0.0001_lr_0=0.1_n=1020_...  1020
#
#    random_state  test_acc  test_nll
# 0          1001  0.853202  0.675011
# 1          2001  0.866876  0.629629
# 2          3001  0.863317  0.634219
# 3          1001  0.931542  0.347675
# 4          2001  0.930701  0.330521
# 5          3001  0.933074  0.315685

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0     l2-sp   510  (l2-sp_alpha=1e-06_beta=1e-06_lr_0=0.1_n=510_r...
# 1     l2-sp  1020  (l2-sp_alpha=0.0_beta=0.0_lr_0=0.1_n=1020_rand...
#
#          random_state                                           test_acc  \
# 0  (1001, 2001, 3001)  (0.8532021045684814, 0.8668757677078247, 0.863...
# 1  (1001, 2001, 3001)  (0.9315415620803832, 0.9307012557983398, 0.933...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.6750107475100997, 0.6296289651056399, 0.634...       0.861132
# 1  (0.347674924849946, 0.3305205590603899, 0.3156...       0.931772
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.005792      0.853202      0.866876       0.646286      0.020398
# 1      0.000982      0.930701      0.933074       0.331294      0.013071
#
#    test_nll_min  test_nll_max
# 0      0.629629      0.675011
# 1      0.315685      0.347675

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0     l2-sp   510       0.861132      0.853202      0.866876
# 1     l2-sp  1020       0.931772      0.930701      0.933074

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0     l2-sp   510       0.646286      0.629629      0.675011
# 1     l2-sp  1020       0.331294      0.315685      0.347675

# %%
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'ptyl'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_SSL'
lambds = np.logspace(start=0, stop=9, num=10)
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

count = -1
for beta, lambd, lr_0, n, random_state in itertools.product(betas, lambds, lr_0s, ns, random_states):
    model_name = f'{criterion}_beta={beta}_lambd={lambd}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        tuned_df.loc[len(tuned_df)] = row
    
min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/retrained_Flowers_102_SSL'

columns = ['criterion', 'model_name', 'n', 'random_state', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row

retrained_df
# Out:
#   criterion                                         model_name     n  \
# 0      ptyl  ptyl_beta=0.0_lambd=100.0_lr_0=0.1_n=510_rando...   510
# 1      ptyl  ptyl_beta=0.0_lambd=100.0_lr_0=0.1_n=510_rando...   510
# 2      ptyl  ptyl_beta=0.0001_lambd=100.0_lr_0=0.1_n=510_ra...   510
# 3      ptyl  ptyl_beta=0.001_lambd=100000000.0_lr_0=0.1_n=1...  1020
# 4      ptyl  ptyl_beta=0.0001_lambd=10.0_lr_0=0.1_n=1020_ra...  1020
# 5      ptyl  ptyl_beta=0.0001_lambd=100.0_lr_0=0.1_n=1020_r...  1020
#
#    random_state  test_acc  test_nll
# 0          1001  0.809471  0.859306
# 1          2001  0.820477  0.851634
# 2          3001  0.827764  0.808247
# 3          1001  0.896939  0.492196
# 4          2001  0.901413  0.461228
# 5          3001  0.892305  0.513435

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0      ptyl   510  (ptyl_beta=0.0_lambd=100.0_lr_0=0.1_n=510_rand...
# 1      ptyl  1020  (ptyl_beta=0.001_lambd=100000000.0_lr_0=0.1_n=...
#
#          random_state                                           test_acc  \
# 0  (1001, 2001, 3001)  (0.8094708919525146, 0.8204765319824219, 0.827...
# 1  (1001, 2001, 3001)  (0.896939218044281, 0.9014132618904114, 0.8923...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.8593063579656345, 0.8516342300323566, 0.808...       0.819237
# 1  (0.4921957659278386, 0.4612277829759083, 0.513...       0.896886
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.007519      0.809471      0.827764       0.839729      0.022481
# 1      0.003719      0.892305      0.901413       0.488953      0.021436
#
#    test_nll_min  test_nll_max
# 0      0.808247      0.859306
# 1      0.461228      0.513435

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0      ptyl   510       0.819237      0.809471      0.827764
# 1      ptyl  1020       0.896886      0.892305      0.901413

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0      ptyl   510       0.839729      0.808247      0.859306
# 1      ptyl  1020       0.488953      0.461228      0.513435

# %%
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'ptyl'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102'
lambds = np.logspace(start=0, stop=9, num=10)
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

count = -1
for beta, lambd, lr_0, n, random_state in itertools.product(betas, lambds, lr_0s, ns, random_states):
    model_name = f'{criterion}_beta={beta}_lambd={lambd}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        tuned_df.loc[len(tuned_df)] = row
    
min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/retrained_Flowers_102'

columns = ['criterion', 'model_name', 'n', 'random_state', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row

retrained_df
# Out:
#   criterion                                         model_name     n  \
# 0      ptyl  ptyl_beta=1e-05_lambd=10000.0_lr_0=0.1_n=510_r...   510
# 1      ptyl  ptyl_beta=0.0_lambd=100000.0_lr_0=0.1_n=510_ra...   510
# 2      ptyl  ptyl_beta=1e-06_lambd=1000.0_lr_0=0.1_n=510_ra...   510
# 3      ptyl  ptyl_beta=0.0_lambd=100000000.0_lr_0=0.1_n=102...  1020
# 4      ptyl  ptyl_beta=1e-05_lambd=100000000.0_lr_0=0.1_n=1...  1020
# 5      ptyl  ptyl_beta=0.0001_lambd=100000.0_lr_0=0.1_n=102...  1020
#
#    random_state  test_acc  test_nll
# 0          1001  0.857836  0.675746
# 1          2001  0.866010  0.630066
# 2          3001  0.865124  0.631908
# 3          1001  0.931298  0.335795
# 4          2001  0.931068  0.323245
# 5          3001  0.925769  0.327369

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0      ptyl   510  (ptyl_beta=1e-05_lambd=10000.0_lr_0=0.1_n=510_...
# 1      ptyl  1020  (ptyl_beta=0.0_lambd=100000000.0_lr_0=0.1_n=10...
#
#          random_state                                           test_acc  \
# 0  (1001, 2001, 3001)  (0.8578360080718994, 0.8660104274749756, 0.865...
# 1  (1001, 2001, 3001)  (0.9312978386878968, 0.9310680627822876, 0.925...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.6757463747349225, 0.6300655637877993, 0.631...       0.862990
# 1  (0.33579462177171, 0.3232451387625941, 0.32736...       0.929378
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.003663      0.857836      0.866010       0.645907      0.021113
# 1      0.002554      0.925769      0.931298       0.328803      0.005223
#
#    test_nll_min  test_nll_max
# 0      0.630066      0.675746
# 1      0.323245      0.335795

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0      ptyl   510       0.862990      0.857836      0.866010
# 1      ptyl  1020       0.929378      0.925769      0.931298

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0      ptyl   510       0.645907      0.630066      0.675746
# 1      ptyl  1020       0.328803      0.323245      0.335795

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/retrained_Flowers_102_ViT_B_16'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
model_arch = 'ViT-B/16'
ns = [510, 1020]
prior_directory = '{home_dir}/vit_b_16_torchvision'
prior_type = 'vit_b_16_torchvision'
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(128, n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state}"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state}"')
print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_ViT_B_16'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        tuned_df.loc[len(tuned_df)] = row
    
min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/retrained_Flowers_102_ViT_B_16'

columns = ['criterion', 'model_name', 'n', 'random_state', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row
        
retrained_df
# Out:
#   criterion                                         model_name     n  \
# 0     l2-sp  l2-sp_alpha=1e-05_beta=1e-05_lr_0=0.01_n=510_r...   510
# 1     l2-sp  l2-sp_alpha=1e-06_beta=1e-05_lr_0=0.01_n=510_r...   510
# 2     l2-sp  l2-sp_alpha=0.0_beta=0.0_lr_0=0.01_n=510_rando...   510
# 3     l2-sp  l2-sp_alpha=0.0_beta=0.0_lr_0=0.01_n=1020_rand...  1020
# 4     l2-sp  l2-sp_alpha=1e-06_beta=0.0_lr_0=0.01_n=1020_ra...  1020
# 5     l2-sp  l2-sp_alpha=0.0_beta=0.0001_lr_0=0.1_n=1020_ra...  1020
#
#    random_state  test_acc  test_nll
# 0          1001  0.849494  0.709829
# 1          2001  0.858963  0.723120
# 2          3001  0.866062  0.643223
# 3          1001  0.930458  0.342477
# 4          2001  0.926925  0.360174
# 5          3001  0.883197  0.543721

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0     l2-sp   510  (l2-sp_alpha=1e-05_beta=1e-05_lr_0=0.01_n=510_...
# 1     l2-sp  1020  (l2-sp_alpha=0.0_beta=0.0_lr_0=0.01_n=1020_ran...
#
#          random_state                                           test_acc  \
# 0  (1001, 2001, 3001)  (0.8494938015937805, 0.858963131904602, 0.8660...
# 1  (1001, 2001, 3001)  (0.9304575324058532, 0.9269248843193054, 0.883...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.7098291885379776, 0.7231197805012277, 0.643...       0.858173
# 1  (0.3424774820588142, 0.3601737110343168, 0.543...       0.913526
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.006787      0.849494      0.866062       0.692057      0.034955
# 1      0.021495      0.883197      0.930458       0.415457      0.090983
#
#    test_nll_min  test_nll_max
# 0      0.643223      0.723120
# 1      0.342477      0.543721

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0     l2-sp   510       0.858173      0.849494      0.866062
# 1     l2-sp  1020       0.913526      0.883197      0.930458

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0     l2-sp   510       0.692057      0.643223      0.723120
# 1     l2-sp  1020       0.415457      0.342477      0.543721

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/retrained_Flowers_102_ConvNeXt_Tiny'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
model_arch = 'ConvNeXt_Tiny'
ns = [510, 1020]
prior_directory = '{home_dir}/convnext_tiny_torchvision'
prior_type = 'convnext_tiny_torchvision'
random_states = [1001, 2001, 3001]

count = -1
for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        if not check_epochs(temp_df, n, batch_size=min(128, n), steps=6000):
            count += 1
            print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state}"')
    else:
        count += 1
        print(f'    "python ../src/main_Flowers_102.py --alpha={alpha} --beta={beta} --batch_size=128 --criterion=\'{criterion}\' --dataset_directory=\'{dataset_directory}\' --experiments_directory=\'{experiments_directory}\' --lr_0={lr_0} --model_arch=\'{model_arch}\' --model_name=\'{model_name}\' --n={n} --num_workers=0 --prior_directory=\'{prior_directory}\' --prior_type=\'{prior_type}\' --random_state={random_state}"')
print(count)
# Out:
# -1

# %%
alphas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
betas = [0.01, 0.001, 0.0001, 1e-05, 1e-06, 0.0]
criterion = 'l2-sp'
dataset_directory = '{home_dir}/Flowers_102'
experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/tuned_Flowers_102_ConvNeXt_Tiny'
lr_0s = [0.1, 0.01, 0.001, 0.0001]
ns = [510, 1020]
random_states = [1001, 2001, 3001]

columns = ['criterion', 'model_name', 'n', 'random_state', 'val_acc', 'val_nll']
tuned_df = pd.DataFrame(columns=columns)

for alpha, beta, lr_0, n, random_state in itertools.product(alphas, betas, lr_0s, ns, random_states):
    model_name = f'{criterion}_alpha={alpha}_beta={beta}_lr_0={lr_0}_n={n}_random_state={random_state}'
    if os.path.exists(f'{experiments_directory}/{model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{model_name}.csv')
        row = [criterion, model_name, n, random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        tuned_df.loc[len(tuned_df)] = row
    
min_indices = tuned_df.groupby(['criterion', 'n', 'random_state'])['val_nll'].idxmin()
tuned_df = tuned_df.loc[min_indices]

experiments_directory = '{home_dir}/data-emphasized-ELBo/experiments/retrained_Flowers_102_ConvNeXt_Tiny'

columns = ['criterion', 'model_name', 'n', 'random_state', 'test_acc', 'test_nll']
retrained_df = pd.DataFrame(columns=columns)

for index, row in tuned_df.iterrows():
    if os.path.exists(f'{experiments_directory}/{row.model_name}.csv'):
        temp_df = pd.read_csv(f'{experiments_directory}/{row.model_name}.csv')
        row = [row.criterion, row.model_name, row.n, row.random_state, temp_df.val_or_test_acc.values[-1], temp_df.val_or_test_nll.values[-1]]
        retrained_df.loc[len(retrained_df)] = row
        
retrained_df
# Out:
#   criterion                                         model_name     n  \
# 0     l2-sp  l2-sp_alpha=0.0_beta=1e-05_lr_0=0.01_n=510_ran...   510
# 1     l2-sp  l2-sp_alpha=1e-06_beta=0.0_lr_0=0.01_n=510_ran...   510
# 2     l2-sp  l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=510_ran...   510
# 3     l2-sp  l2-sp_alpha=1e-06_beta=0.0_lr_0=0.01_n=1020_ra...  1020
# 4     l2-sp  l2-sp_alpha=0.01_beta=0.001_lr_0=0.1_n=1020_ra...  1020
# 5     l2-sp  l2-sp_alpha=0.0_beta=1e-06_lr_0=0.01_n=1020_ra...  1020
#
#    random_state  test_acc  test_nll
# 0          1001  0.882666  0.556597
# 1          2001  0.885072  0.514189
# 2          3001  0.892639  0.552080
# 3          1001  0.944327  0.231539
# 4          2001  0.957013  0.233622
# 5          3001  0.923311  0.382816

# %%
grouped_df = retrained_df.groupby(['criterion', 'n']).agg(lambda x: tuple(x))
columns = ['test_acc', 'test_nll']
for column in columns:
    grouped_df[f'{column}_mean'] = grouped_df[column].apply(lambda item: np.mean(item))
    grouped_df[f'{column}_std'] = grouped_df[column].apply(lambda item: np.std(item))
    grouped_df[f'{column}_min'] = grouped_df[column].apply(lambda item: np.min(item))
    grouped_df[f'{column}_max'] = grouped_df[column].apply(lambda item: np.max(item))
grouped_df = grouped_df.reset_index()
grouped_df
# Out:
#   criterion     n                                         model_name  \
# 0     l2-sp   510  (l2-sp_alpha=0.0_beta=1e-05_lr_0=0.01_n=510_ra...
# 1     l2-sp  1020  (l2-sp_alpha=1e-06_beta=0.0_lr_0=0.01_n=1020_r...
#
#          random_state                                           test_acc  \
# 0  (1001, 2001, 3001)  (0.8826658129692078, 0.8850719928741455, 0.892...
# 1  (1001, 2001, 3001)  (0.9443271160125732, 0.9570127129554749, 0.923...
#
#                                             test_nll  test_acc_mean  \
# 0  (0.5565970626938831, 0.5141889152948509, 0.552...       0.886792
# 1  (0.2315391923013073, 0.2336219061641025, 0.382...       0.941550
#
#    test_acc_std  test_acc_min  test_acc_max  test_nll_mean  test_nll_std  \
# 0      0.004249      0.882666      0.892639       0.540955      0.019016
# 1      0.013898      0.923311      0.957013       0.282659      0.070827
#
#    test_nll_min  test_nll_max
# 0      0.514189      0.556597
# 1      0.231539      0.382816

# %%
grouped_df[['criterion', 'n', 'test_acc_mean', 'test_acc_min', 'test_acc_max']]
# Out:
#   criterion     n  test_acc_mean  test_acc_min  test_acc_max
# 0     l2-sp   510       0.886792      0.882666      0.892639
# 1     l2-sp  1020       0.941550      0.923311      0.957013

# %%
grouped_df[['criterion', 'n', 'test_nll_mean', 'test_nll_min', 'test_nll_max']]
# Out:
#   criterion     n  test_nll_mean  test_nll_min  test_nll_max
# 0     l2-sp   510       0.540955      0.514189      0.556597
# 1     l2-sp  1020       0.282659      0.231539      0.382816
